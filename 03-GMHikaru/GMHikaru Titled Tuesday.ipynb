# %% [markdown]
# # Hikaru Nakamura Titled Tuesday Analysis

# %% [markdown]
# Titled Tuesday is Chess.com's weekly 11-round Swiss tournament for titled players, occurring twice each Tuesday since February 1, 2022. <br>
# The analysis include data collected from chess.com API ([tutorial](https://www.chess.com/news/view/published-data-api#pubapi-endpoint-player-tournaments)) and span form 06/2015 to 09/2022

# %%
import pandas as pd
import requests
import datetime
import json

# %% [markdown]
# ## Get all the games played

# %%
# the API divide the games in months
url = 'https://api.chess.com/pub/player/hikaru/games/archives'

# get all the months links
months = requests.get(url).content.decode()
months = json.loads(months)
months = months['archives']

# %%
months
# Out:
# ['https://api.chess.com/pub/player/hikaru/games/2014/01',
#  'https://api.chess.com/pub/player/hikaru/games/2014/02',
#  'https://api.chess.com/pub/player/hikaru/games/2014/03',
#  'https://api.chess.com/pub/player/hikaru/games/2014/04',
#  'https://api.chess.com/pub/player/hikaru/games/2014/05',
#  'https://api.chess.com/pub/player/hikaru/games/2014/06',
#  'https://api.chess.com/pub/player/hikaru/games/2014/07',
#  'https://api.chess.com/pub/player/hikaru/games/2014/08',
#  'https://api.chess.com/pub/player/hikaru/games/2014/09',
#  'https://api.chess.com/pub/player/hikaru/games/2014/10',
#  'https://api.chess.com/pub/player/hikaru/games/2014/11',
#  'https://api.chess.com/pub/player/hikaru/games/2014/12',
#  'https://api.chess.com/pub/player/hikaru/games/2015/01',
#  'https://api.chess.com/pub/player/hikaru/games/2015/02',
#  'https://api.chess.com/pub/player/hikaru/games/2015/03',
#  'https://api.chess.com/pub/player/hikaru/games/2015/04',
#  'https://api.chess.com/pub/player/hikaru/games/2015/05',
#  'https://api.chess.com/pub/player/hikaru/games/2015/06',
#  'https://api.chess.com/pub/player/hikaru/games/2015/07',
#  'https://api.chess.com/pub/player/hikaru/games/2015/08',
#  'https://api.chess.com/pub/player/hikaru/games/2015/09',
#  'https://api.chess.com/pub/player/hikaru/games/2015/10',
#  'https://api.chess.com/pub/player/hikaru/games/2015/11',
#  'https://api.chess.com/pub/player/hikaru/games/2015/12',
#  'https://api.chess.com/pub/player/hikaru/games/2016/01',
#  'https://api.chess.com/pub/player/hikaru/games/2016/02',
#  'https://api.chess.com/pub/player/hikaru/games/2016/03',
#  'https://api.chess.com/pub/player/hikaru/games/2016/04',
#  'https://api.chess.com/pub/player/hikaru/games/2016/05',
#  'https://api.chess.com/pub/player/hikaru/games/2016/06',
#  'https://api.chess.com/pub/player/hikaru/games/2016/07',
#  'https://api.chess.com/pub/player/hikaru/games/2016/08',
#  'https://api.chess.com/pub/player/hikaru/games/2016/09',
#  'https://api.chess.com/pub/player/hikaru/games/2016/10',
#  'https://api.chess.com/pub/player/hikaru/games/2016/11',
#  'https://api.chess.com/pub/player/hikaru/games/2016/12',
#  'https://api.chess.com/pub/player/hikaru/games/2017/01',
#  'https://api.chess.com/pub/player/hikaru/games/2017/02',
#  'https://api.chess.com/pub/player/hikaru/games/2017/03',
#  'https://api.chess.com/pub/player/hikaru/games/2017/04',
#  'https://api.chess.com/pub/player/hikaru/games/2017/05',
#  'https://api.chess.com/pub/player/hikaru/games/2017/06',
#  'https://api.chess.com/pub/player/hikaru/games/2017/07',
#  'https://api.chess.com/pub/player/hikaru/games/2017/08',
#  'https://api.chess.com/pub/player/hikaru/games/2017/09',
#  'https://api.chess.com/pub/player/hikaru/games/2017/10',
#  'https://api.chess.com/pub/player/hikaru/games/2017/11',
#  'https://api.chess.com/pub/player/hikaru/games/2017/12',
#  'https://api.chess.com/pub/player/hikaru/games/2018/01',
#  'https://api.chess.com/pub/player/hikaru/games/2018/02',
#  'https://api.chess.com/pub/player/hikaru/games/2018/03',
#  'https://api.chess.com/pub/player/hikaru/games/2018/04',
#  'https://api.chess.com/pub/player/hikaru/games/2018/05',
#  'https://api.chess.com/pub/player/hikaru/games/2018/06',
#  'https://api.chess.com/pub/player/hikaru/games/2018/07',
#  'https://api.chess.com/pub/player/hikaru/games/2018/08',
#  'https://api.chess.com/pub/player/hikaru/games/2018/09',
#  'https://api.chess.com/pub/player/hikaru/games/2018/10',
#  'https://api.chess.com/pub/player/hikaru/games/2018/11',
#  'https://api.chess.com/pub/player/hikaru/games/2018/12',
#  'https://api.chess.com/pub/player/hikaru/games/2019/01',
#  'https://api.chess.com/pub/player/hikaru/games/2019/02',
#  'https://api.chess.com/pub/player/hikaru/games/2019/03',
#  'https://api.chess.com/pub/player/hikaru/games/2019/04',
#  'https://api.chess.com/pub/player/hikaru/games/2019/05',
#  'https://api.chess.com/pub/player/hikaru/games/2019/06',
#  'https://api.chess.com/pub/player/hikaru/games/2019/07',
#  'https://api.chess.com/pub/player/hikaru/games/2019/08',
#  'https://api.chess.com/pub/player/hikaru/games/2019/09',
#  'https://api.chess.com/pub/player/hikaru/games/2019/10',
#  'https://api.chess.com/pub/player/hikaru/games/2019/11',
#  'https://api.chess.com/pub/player/hikaru/games/2019/12',
#  'https://api.chess.com/pub/player/hikaru/games/2020/01',
#  'https://api.chess.com/pub/player/hikaru/games/2020/02',
#  'https://api.chess.com/pub/player/hikaru/games/2020/03',
#  'https://api.chess.com/pub/player/hikaru/games/2020/04',
#  'https://api.chess.com/pub/player/hikaru/games/2020/05',
#  'https://api.chess.com/pub/player/hikaru/games/2020/06',
#  'https://api.chess.com/pub/player/hikaru/games/2020/07',
#  'https://api.chess.com/pub/player/hikaru/games/2020/08',
#  'https://api.chess.com/pub/player/hikaru/games/2020/09',
#  'https://api.chess.com/pub/player/hikaru/games/2020/10',
#  'https://api.chess.com/pub/player/hikaru/games/2020/11',
#  'https://api.chess.com/pub/player/hikaru/games/2020/12',
#  'https://api.chess.com/pub/player/hikaru/games/2021/01',
#  'https://api.chess.com/pub/player/hikaru/games/2021/02',
#  'https://api.chess.com/pub/player/hikaru/games/2021/03',
#  'https://api.chess.com/pub/player/hikaru/games/2021/04',
#  'https://api.chess.com/pub/player/hikaru/games/2021/05',
#  'https://api.chess.com/pub/player/hikaru/games/2021/06',
#  'https://api.chess.com/pub/player/hikaru/games/2021/07',
#  'https://api.chess.com/pub/player/hikaru/games/2021/08',
#  'https://api.chess.com/pub/player/hikaru/games/2021/09',
#  'https://api.chess.com/pub/player/hikaru/games/2021/10',
#  'https://api.chess.com/pub/player/hikaru/games/2021/11',
#  'https://api.chess.com/pub/player/hikaru/games/2021/12',
#  'https://api.chess.com/pub/player/hikaru/games/2022/01',
#  'https://api.chess.com/pub/player/hikaru/games/2022/02',
#  'https://api.chess.com/pub/player/hikaru/games/2022/03',
#  'https://api.chess.com/pub/player/hikaru/games/2022/04',
#  'https://api.chess.com/pub/player/hikaru/games/2022/05',
#  'https://api.chess.com/pub/player/hikaru/games/2022/06',
#  'https://api.chess.com/pub/player/hikaru/games/2022/07',
#  'https://api.chess.com/pub/player/hikaru/games/2022/08',
#  'https://api.chess.com/pub/player/hikaru/games/2022/09']

# %%
# let's see how are the game formatted
url = months[-1]

# get all the games
games = requests.get(url).content.decode()
games = json.loads(games)
games = games['games']

# %%
# the info we need are in the pgn 
games[0]['pgn'].split('\n')
# Out:
# ['[Event "Live Chess"]',
#  '[Site "Chess.com"]',
#  '[Date "2022.09.01"]',
#  '[Round "-"]',
#  '[White "Hikaru"]',
#  '[Black "TampaChess"]',
#  '[Result "1-0"]',
#  '[CurrentPosition "5knQ/2p2r1p/1p1p4/3P1qB1/4R2P/r4BP1/5P2/5RK1 b - -"]',
#  '[Timezone "UTC"]',
#  '[ECO "A00"]',
#  '[ECOUrl "https://www.chess.com/openings/Kings-Fianchetto-Opening-1...e5-2.Bg2"]',
#  '[UTCDate "2022.09.01"]',
#  '[UTCTime "15:50:11"]',
#  '[WhiteElo "3202"]',
#  '[BlackElo "2821"]',
#  '[TimeControl "180"]',
#  '[Termination "Hikaru won by resignation"]',
#  '[StartTime "15:50:11"]',
#  '[EndDate "2022.09.01"]',
#  '[EndTime "15:55:06"]',
#  '[Link "https://www.chess.com/game/live/55786465275"]',
#  '',
#  '1. g3 {[%clk 0:03:00]} 1... e5 {[%clk 0:03:00]} 2. Bg2 {[%clk 0:02:59.5]} 2... Nc6 {[%clk 0:02:59.6]} 3. c4 {[%clk 0:02:49.7]} 3... g6 {[%clk 0:02:54.3]} 4. Nc3 {[%clk 0:02:49.6]} 4... Bg7 {[%clk 0:02:53.7]} 5. a3 {[%clk 0:02:48.9]} 5... d6 {[%clk 0:02:53.2]} 6. b4 {[%clk 0:02:48.2]} 6... a6 {[%clk 0:02:51.1]} 7. Rb1 {[%clk 0:02:47.3]} 7... Be6 {[%clk 0:02:49.5]} 8. d3 {[%clk 0:02:46.1]} 8... f5 {[%clk 0:02:47]} 9. b5 {[%clk 0:02:43]} 9... axb5 {[%clk 0:02:45.7]} 10. Rxb5 {[%clk 0:02:42.5]} 10... Qc8 {[%clk 0:02:22.9]} 11. e3 {[%clk 0:02:38.7]} 11... e4 {[%clk 0:02:13.6]} 12. Nd5 {[%clk 0:02:22.9]} 12... exd3 {[%clk 0:02:11.6]} 13. Qxd3 {[%clk 0:02:22.8]} 13... Nge7 {[%clk 0:02:05.4]} 14. Ne2 {[%clk 0:02:18.5]} 14... Ne5 {[%clk 0:02:01]} 15. Qb1 {[%clk 0:02:15.9]} 15... Bxd5 {[%clk 0:01:44.2]} 16. cxd5 {[%clk 0:02:15.3]} 16... b6 {[%clk 0:01:38.4]} 17. Nf4 {[%clk 0:02:14.1]} 17... O-O {[%clk 0:01:24.3]} 18. Ne6 {[%clk 0:02:11.3]} 18... Rf7 {[%clk 0:01:23.8]} 19. Nxg7 {[%clk 0:02:10.7]} 19... Kxg7 {[%clk 0:01:22.1]} 20. O-O {[%clk 0:02:09.8]} 20... Kg8 {[%clk 0:01:14.1]} 21. Rd1 {[%clk 0:02:06.6]} 21... Nd7 {[%clk 0:01:13.3]} 22. Bb2 {[%clk 0:02:04.4]} 22... Nc5 {[%clk 0:01:11.5]} 23. Qc2 {[%clk 0:02:03.2]} 23... Qd7 {[%clk 0:01:09.6]} 24. Qc3 {[%clk 0:02:00.7]} 24... Kf8 {[%clk 0:01:07.7]} 25. Rb4 {[%clk 0:01:59.2]} 25... Na4 {[%clk 0:01:00]} 26. Qh8+ {[%clk 0:01:57.8]} 26... Ng8 {[%clk 0:00:59.6]} 27. Ba1 {[%clk 0:01:54.5]} 27... Nc5 {[%clk 0:00:58.3]} 28. Bb2 {[%clk 0:01:52.3]} 28... Na4 {[%clk 0:00:57.1]} 29. Bc1 {[%clk 0:01:51.4]} 29... Nc5 {[%clk 0:00:56.7]} 30. e4 {[%clk 0:01:50.7]} 30... fxe4 {[%clk 0:00:55.4]} 31. Bh6+ {[%clk 0:01:49.1]} 31... Ke7 {[%clk 0:00:52.7]} 32. Bg5+ {[%clk 0:01:48.3]} 32... Kf8 {[%clk 0:00:51.7]} 33. Re1 {[%clk 0:01:38.3]} 33... Qf5 {[%clk 0:00:38.3]} 34. Be3 {[%clk 0:01:37.1]} 34... Nd3 {[%clk 0:00:36.4]} 35. Rxe4 {[%clk 0:01:32.9]} 35... g5 {[%clk 0:00:25.9]} 36. Rf1 {[%clk 0:01:26.5]} 36... Rxa3 {[%clk 0:00:25.2]} 37. h4 {[%clk 0:01:20.1]} 37... Ne5 {[%clk 0:00:24]} 38. Bxg5 {[%clk 0:01:18.3]} 38... Nf3+ {[%clk 0:00:19.8]} 39. Bxf3 {[%clk 0:01:17.5]} 1-0',
#  '']

# %%
# we need a function for processing the data in a more digestible form

def better_form(game):
    # given the data as string it return them as a dictionarie
    dic = {}
    for info in game:
        key = info[1:info.index('"')-1] 
        value = info[info.index('"')+1:-2] # exploit that the 'content' is between "..."
        dic[key] = value
    return dic

# %%
all_games = []
for month in months:
    url = month
    games = requests.get(url).content.decode()
    games = json.loads(games)
    games = games['games']

    for game in games:
        try:
            # we will not need the moves for the analysis
            game = game['pgn'].split('\n')[:-3]
        except:
            # necessary since some games are different variation from the tradional chess games
            # and they do not have a pgn field
            continue
        all_games.append(better_form(game))

# %%
# convert the dictionaries in a dataframe
df = pd.DataFrame(all_games)
df
# Out:
#             Event       Site        Date Round              White  \
# 0      Live Chess  Chess.com  2014.01.06     -             Hikaru
# 1      Live Chess  Chess.com  2014.01.06     -           Godswill
# 2      Live Chess  Chess.com  2014.01.07     -       manueliux_06
# 3      Live Chess  Chess.com  2014.01.07     -             Hikaru
# 4      Live Chess  Chess.com  2014.01.07     -             Hikaru
# ...           ...        ...         ...   ...                ...
# 44866  Live Chess  Chess.com  2022.09.07     -         DesiAttack
# 44867  Live Chess  Chess.com  2022.09.07     -             Hikaru
# 44868  Live Chess  Chess.com  2022.09.07     -  Oleksandr_Bortnyk
# 44869  Live Chess  Chess.com  2022.09.10     -      NikoTheodorou
# 44870  Live Chess  Chess.com  2022.09.10     -             Hikaru
#
#                      Black   Result  \
# 0                 Godswill      1-0
# 1                   Hikaru      0-1
# 2                   Hikaru      0-1
# 3             manueliux_06      1-0
# 4      Dmitriy_From_Russia      1-0
# ...                    ...      ...
# 44866               Hikaru      0-1
# 44867             jcibarra      1-0
# 44868               Hikaru      0-1
# 44869               Hikaru      0-1
# 44870        NikoTheodorou  1/2-1/2
#
#                                          CurrentPosition Timezone  ECO  ...  \
# 0            6k1/1p2R3/p1p5/8/2P1B3/1P1P1p1P/P6K/8 b - -      UTC  C25  ...
# 1                      8/8/7p/7P/1p6/pBkpp2b/8/4K3 w - -      UTC  A50  ...
# 2      rnb3k1/5ppp/2p5/p1b5/1p3B2/6P1/PPPNr1KP/R4R2 w...      UTC  C25  ...
# 3                     8/p7/R6p/5pk1/8/6P1/P4P2/6K1 b - -      UTC  B10  ...
# 4        2R5/1p3rkp/1B1p1bp1/p2Pp3/P3B3/6PP/5P1K/8 b - -      UTC  B07  ...
# ...                                                  ...      ...  ...  ...
# 44866  4r1kr/p2n2pp/4Nn2/1P1b4/2BB4/2P5/P4P1P/R3K3 w Q -      UTC  A40  ...
# 44867  r1b2rk1/1p1nq1bp/p3N1p1/2ppP3/5PP1/1P2B1QP/P1P...      UTC  A00  ...
# 44868  2r1k2r/pb1qbp1p/1p1pp1p1/n7/P2PB3/B1P4Q/2PN1PP...      UTC  C00  ...
# 44869               8/8/4pk2/1R4p1/5P2/8/1p4K1/1r6 w - -      UTC  A48  ...
# 44870                        7k/7P/6K1/6B1/8/8/8/8 b - -      UTC  B22  ...
#
#       TimeControl                Termination StartTime     EndDate   EndTime  \
# 0             180  Hikaru won by resignation  23:50:17  2014.01.06  23:54:39
# 1             180         Hikaru won on time  23:54:43  2014.01.07  00:00:32
# 2              60  Hikaru won by resignation  00:34:20  2014.01.07  00:35:05
# 3              60  Hikaru won by resignation  00:35:52  2014.01.07  00:37:45
# 4             180  Hikaru won by resignation  00:43:10  2014.01.07  00:46:10
# ...           ...                        ...       ...         ...       ...
# 44866         180  Hikaru won by resignation  17:53:12  2022.09.07  17:55:23
# 44867         180  Hikaru won by resignation  17:55:20  2022.09.07  17:56:27
# 44868         180  Hikaru won by resignation  17:56:24  2022.09.07  17:58:16
# 44869         180  Hikaru won by resignation  00:54:15  2022.09.10  00:59:52
# 44870         180    Game drawn by stalemate  00:59:21  2022.09.10  01:05:58
#
#                                               Link SetUp  FEN Variant  \
# 0        https://www.chess.com/game/live/692667823   NaN  NaN     NaN
# 1        https://www.chess.com/game/live/692670646   NaN  NaN     NaN
# 2        https://www.chess.com/game/live/692695595   NaN  NaN     NaN
# 3        https://www.chess.com/game/live/692696567   NaN  NaN     NaN
# 4        https://www.chess.com/game/live/692700868   NaN  NaN     NaN
# ...                                            ...   ...  ...     ...
# 44866  https://www.chess.com/game/live/56312115537   NaN  NaN     NaN
# 44867  https://www.chess.com/game/live/56312153875   NaN  NaN     NaN
# 44868  https://www.chess.com/game/live/56312171467   NaN  NaN     NaN
# 44869  https://www.chess.com/game/live/56510364391   NaN  NaN     NaN
# 44870  https://www.chess.com/game/live/56510415399   NaN  NaN     NaN
#
#       Tournament
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 44866        NaN
# 44867        NaN
# 44868        NaN
# 44869        NaN
# 44870        NaN
#
# [44871 rows x 25 columns]

# %%
# we have in total almost 45000 games
# we dont need all the fields

df = df.drop(['CurrentPosition','ECOUrl', 'Round', 'Site', 'Event', 'Timezone', 'ECO', 'UTCDate', 'UTCTime', 'SetUp', 'FEN', 'Variant', 'Link'], axis = 1)
df
# Out:
#              Date              White                Black   Result WhiteElo  \
# 0      2014.01.06             Hikaru             Godswill      1-0     2354
# 1      2014.01.06           Godswill               Hikaru      0-1     2163
# 2      2014.01.07       manueliux_06               Hikaru      0-1     2104
# 3      2014.01.07             Hikaru         manueliux_06      1-0     2411
# 4      2014.01.07             Hikaru  Dmitriy_From_Russia      1-0     2509
# ...           ...                ...                  ...      ...      ...
# 44866  2022.09.07         DesiAttack               Hikaru      0-1     2669
# 44867  2022.09.07             Hikaru             jcibarra      1-0     3211
# 44868  2022.09.07  Oleksandr_Bortnyk               Hikaru      0-1     3010
# 44869  2022.09.10      NikoTheodorou               Hikaru      0-1     3007
# 44870  2022.09.10             Hikaru        NikoTheodorou  1/2-1/2     3215
#
#       BlackElo TimeControl                Termination StartTime     EndDate  \
# 0         2167         180  Hikaru won by resignation  23:50:17  2014.01.06
# 1         2438         180         Hikaru won on time  23:54:43  2014.01.07
# 2         2336          60  Hikaru won by resignation  00:34:20  2014.01.07
# 3         2101          60  Hikaru won by resignation  00:35:52  2014.01.07
# 4         2266         180  Hikaru won by resignation  00:43:10  2014.01.07
# ...        ...         ...                        ...       ...         ...
# 44866     3209         180  Hikaru won by resignation  17:53:12  2022.09.07
# 44867     2822         180  Hikaru won by resignation  17:55:20  2022.09.07
# 44868     3215         180  Hikaru won by resignation  17:56:24  2022.09.07
# 44869     3219         180  Hikaru won by resignation  00:54:15  2022.09.10
# 44870     3011         180    Game drawn by stalemate  00:59:21  2022.09.10
#
#         EndTime Tournament
# 0      23:54:39        NaN
# 1      00:00:32        NaN
# 2      00:35:05        NaN
# 3      00:37:45        NaN
# 4      00:46:10        NaN
# ...         ...        ...
# 44866  17:55:23        NaN
# 44867  17:56:27        NaN
# 44868  17:58:16        NaN
# 44869  00:59:52        NaN
# 44870  01:05:58        NaN
#
# [44871 rows x 12 columns]

# %%
# we can save it
df.to_csv('all_games.csv', index = False)

# %% [markdown]
# ## Focus on Titled Tuesday

# %%
# all the titled tuesday games will have an entry in the Tournement field
df = df.dropna()

# %%
# there are other tournament beside TT so we need to identify the one's we care
df['TT'] = df['Tournament'].apply(lambda x: 1 if x.find('titled-tuesday')!= -1 else 0)
# Out:
# C:\Users\matti\AppData\Local\Temp\ipykernel_10592\3842738628.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TT'] = df['Tournament'].apply(lambda x: 1 if x.find('titled-tuesday')!= -1 else 0)

# %%
# we keep only the row that have 'titled-tuesday' substring in the Tournament field
df = df[df['TT'] == 1]

# %%
# we now have only 1645 games
df
# Out:
#              Date          White             Black   Result WhiteElo BlackElo  \
# 2140   2015.02.24         Hikaru  LADIESGET2KNOWME      1-0     2851     2302
# 2141   2015.02.24        9ShMat2            Hikaru      0-1     2433     2852
# 2142   2015.02.24         Hikaru           chito89  1/2-1/2     2847     2593
# 2143   2015.02.24      megarompa            Hikaru      0-1     2641     2851
# 2144   2015.02.24         Hikaru        GMNeiksans      1-0     2853     2522
# ...           ...            ...               ...      ...      ...      ...
# 44836  2022.09.06   Orange_Ghost            Hikaru      0-1     2842     3212
# 44837  2022.09.06         Dedic8            Hikaru      0-1     2863     3214
# 44838  2022.09.06         Hikaru        penguingm1      1-0     3217     2924
# 44839  2022.09.06  Sam_ChessMood            Hikaru      0-1     2888     3219
# 44840  2022.09.06         Hikaru            mbojan      1-0     3221     2851
#
#       TimeControl                Termination StartTime     EndDate   EndTime  \
# 2140        180+2         Hikaru won on time  19:00:05  2015.02.24  19:07:11
# 2141        180+2  Hikaru won by resignation  19:14:49  2015.02.24  19:24:51
# 2142        180+2    Game drawn by stalemate  19:26:27  2015.02.24  19:34:37
# 2143        180+2  Hikaru won by resignation  19:38:48  2015.02.24  19:51:05
# 2144        180+2         Hikaru won on time  19:52:49  2015.02.24  20:03:34
# ...           ...                        ...       ...         ...       ...
# 44836       180+1  Hikaru won by resignation  22:08:33  2022.09.06  22:13:12
# 44837       180+1         Hikaru won on time  22:18:34  2022.09.06  22:25:10
# 44838       180+1         Hikaru won on time  22:34:59  2022.09.06  22:42:10
# 44839       180+1  Hikaru won by resignation  22:44:40  2022.09.06  22:52:53
# 44840       180+1  Hikaru won by resignation  22:56:28  2022.09.06  23:03:26
#
#                                               Tournament  TT
# 2140   https://www.chess.com/tournament/live/-titled-...   1
# 2141   https://www.chess.com/tournament/live/-titled-...   1
# 2142   https://www.chess.com/tournament/live/-titled-...   1
# 2143   https://www.chess.com/tournament/live/-titled-...   1
# 2144   https://www.chess.com/tournament/live/-titled-...   1
# ...                                                  ...  ..
# 44836  https://www.chess.com/tournament/live/late-tit...   1
# 44837  https://www.chess.com/tournament/live/late-tit...   1
# 44838  https://www.chess.com/tournament/live/late-tit...   1
# 44839  https://www.chess.com/tournament/live/late-tit...   1
# 44840  https://www.chess.com/tournament/live/late-tit...   1
#
# [1645 rows x 13 columns]

# %%
# indentify all the TT
tournaments = df['Tournament']
tournaments = tournaments.drop_duplicates()
tournaments = tournaments.tolist()

# %%
# hikaru played in 170 TT
len(tournaments)
# Out:
# 170

# %%
def get_results(row, i):
    # given a row of the df it compute if hikaru won, lost or drew and update the data structure
    if row['Result'] == '0-1':
        if row['White'] == 'Hikaru':
            tot_losses[i] += 1
        else:
            tot_wins[i] += 1
            
    elif row['Result'] == '1-0':
        if row['White'] == 'Hikaru':
            tot_wins[i] += 1
        else:
            tot_losses[i] += 1
            
    else:
        tot_draws[i] += 1

# %%
tot_wins = [0 for i in range(11)]
tot_losses = [0 for i in range(11)]
tot_draws = [0 for i in range(11)]

for tournament in tournaments:
    temp = df[df['Tournament'] == tournament]
    for i in range(len(temp)):
        get_results(temp.iloc[i], i)

# %%
# wins for every round
tot_wins
# Out:
# [159, 143, 136, 134, 115, 108, 104, 97, 93, 59, 55]

# %%
# losses for every round
tot_losses
# Out:
# [5, 14, 14, 12, 21, 16, 17, 22, 17, 24, 19]

# %%
# draws for every round
tot_draws
# Out:
# [6, 9, 16, 17, 23, 35, 35, 30, 33, 37, 20]

# %%
# we can check the number of games per round
for i in range(11):
    print(tot_wins[i]+tot_losses[i]+tot_draws[i])

# they decrease with every round (early quitting)
# note: round 10 and 11 were introduced later
# Out:
# 170
# 166
# 166
# 163
# 159
# 159
# 156
# 149
# 143
# 120
# 94

# %%
# we now want to compute the opponent average rating for each round
def get_opponent_rating(row, i):
    # given a df row it return the opponent rating
    # it add it to the data struture we are using
    if row['White'] == 'Hikaru':
        rating[i] += int(row['BlackElo'])
    else:
        rating[i] += int(row['WhiteElo'])
    return rating

# %%
rating = [0 for i in range(11)]

for tournament in tournaments:
    # consider only tha games from the specific tournament
    temp = df[df['Tournament'] == tournament]
    
    for i in range(len(temp)):
        # games are altready ordered as the rounds
        rating = get_opponent_rating(temp.iloc[i], i)

for i in range(11):
    # to make the average we need to know the number of games played in the specific round
    tot = tot_wins[i] + tot_losses[i] + tot_draws[i]
    rating[i] = round(rating[i]/tot)

# %%
# average opponent rating for each round
rating
# Out:
# [2470, 2592, 2661, 2708, 2766, 2802, 2831, 2875, 2877, 2942, 2952]

# %% [markdown]
# ## Other stats

# %% [markdown]
# ### Record againts each opponent

# %%
white = df['White'].tolist()
black = df['Black'].tolist()
result = df['Result'].tolist()

# %%
# initialize all the opponent
# 'opponent' : [hikaru_won, hikaru_drew, hikaru_lost]
d = {}

for i in range(len(white)):
    if white[i] == 'Hikaru':
        d[black[i]] = [0,0,0]
    else:
        d[white[i]] = [0,0,0]

# %%
# in the 170 TT hikaru played against 752 different players
len(d)
# Out:
# 752

# %%
for i in range(len(white)):
    if white[i] == 'Hikaru':
        if result[i] == '1-0':
            d[black[i]][0] += 1 # hikaru won
        elif result[i] == '0-1':
            d[black[i]][2] += 1 # hikaru lost
        else:
            d[black[i]][1] += 1 # hikaru drew
            
    else:
        if result[i] == '1-0':
            d[white[i]][2] += 1 # hikaru lost
        elif result[i] == '0-1': # hikaru won
            d[white[i]][0] += 1
        else:
            d[white[i]][1] += 1 # hikaru drew

# %%
d
# Out:
# {'LADIESGET2KNOWME': [1, 0, 0],
#  '9ShMat2': [1, 1, 1],
#  'chito89': [4, 1, 1],
#  'megarompa': [1, 1, 0],
#  'GMNeiksans': [2, 0, 0],
#  'LyonBeast': [3, 3, 2],
#  'tac49': [2, 0, 0],
#  'GeorgMeier': [1, 2, 2],
#  'amaidel': [1, 0, 0],
#  'zmaj23': [1, 0, 1],
#  'vovkcoach': [1, 0, 0],
#  'Tilicheev_Viacheslav': [1, 1, 0],
#  'Cryptochess': [4, 1, 0],
#  'ChessTrener': [0, 1, 0],
#  'Imre91': [2, 0, 0],
#  'arnacman': [1, 0, 0],
#  'Tal-Baronfew': [0, 1, 1],
#  'kleinebeer98': [2, 0, 1],
#  'DanielNaroditsky': [3, 5, 1],
#  'Konavets': [2, 0, 0],
#  'facu57': [2, 0, 0],
#  'Dr-Bassem': [2, 0, 0],
#  'Dlugy': [2, 1, 0],
#  'lexiel': [1, 0, 0],
#  'MinhGTrAn': [1, 0, 1],
#  'nijat_a': [1, 1, 1],
#  'VSERGUEI': [0, 1, 0],
#  'KyronGriffith': [1, 0, 0],
#  'GregShahade': [2, 0, 0],
#  'Beca95': [4, 2, 1],
#  'Mugzyyy': [1, 0, 0],
#  'Tesla37': [1, 0, 0],
#  'chessdude': [1, 0, 0],
#  'Frolyanov_D': [1, 0, 0],
#  'AndreyOstrovskiy': [1, 0, 0],
#  'VMikhalevski': [2, 0, 0],
#  'spectralsoul': [1, 0, 0],
#  '1stSecond': [1, 0, 2],
#  'jcibarra': [5, 2, 0],
#  'GMharikrishna': [1, 0, 0],
#  'ZEN-22': [2, 0, 0],
#  'Iball95': [3, 0, 0],
#  'ArnaudovP': [1, 0, 0],
#  'Boryboy': [3, 0, 0],
#  'MITerryble': [5, 4, 1],
#  'Kacparov': [2, 0, 1],
#  'jefferyx': [8, 6, 1],
#  'BellJackson95': [1, 0, 0],
#  'KNVB': [2, 0, 0],
#  'Zlatan56': [1, 1, 0],
#  'FairChess_on_YouTube': [12, 12, 6],
#  'swayamsm': [1, 0, 0],
#  'BahadirOzen': [2, 1, 0],
#  'maciek_92': [4, 1, 0],
#  'chess_player_17': [1, 0, 0],
#  'pKiLz5Rn9b': [2, 0, 0],
#  'AlexanderL': [2, 1, 0],
#  'RitchieBlackmore': [1, 0, 0],
#  'Smirnov_Pavel': [1, 1, 0],
#  'tigra': [2, 0, 1],
#  'FabianEnglert': [1, 0, 0],
#  'Maitreia': [1, 0, 0],
#  'igorkovalenko': [2, 0, 0],
#  'lorcho': [0, 1, 0],
#  'Matibar': [0, 0, 1],
#  'Zazuliak': [2, 0, 0],
#  'dretch': [4, 3, 3],
#  'Malev212': [2, 0, 0],
#  'Yaacovn': [2, 0, 0],
#  'GMHess': [6, 1, 0],
#  'yurisolo': [2, 3, 0],
#  'Noukii': [0, 1, 0],
#  'SenseiJulio': [1, 0, 1],
#  'chessking2151': [2, 0, 0],
#  'vellottiwizard': [1, 0, 0],
#  'Izoria123': [2, 2, 0],
#  'GrigorGrigorov': [1, 0, 0],
#  'GM_Huschenbeth': [1, 0, 0],
#  'Lupul_Cenusiu': [2, 0, 0],
#  'Winehouse83': [1, 0, 0],
#  'ChessWarrior7197': [3, 2, 3],
#  'yian123': [1, 0, 0],
#  'cool64chess': [1, 0, 0],
#  'Gevorg_Harutjunyan': [0, 2, 0],
#  'iturrizaga': [0, 1, 1],
#  'GianmarcoVaR': [5, 0, 0],
#  'Mornar1951': [1, 0, 0],
#  'TheCount': [1, 0, 0],
#  'yarosavich': [1, 0, 0],
#  'E-Shaposhnikov': [1, 1, 0],
#  'Gabrielian_Artur': [3, 0, 0],
#  'Cayse': [4, 1, 1],
#  'Tonychess32': [1, 0, 0],
#  'LaStreetCmaMaison': [1, 0, 0],
#  'EltajSafarli': [0, 1, 1],
#  'OparinGrigoriy': [10, 1, 0],
#  'JusticeBot': [1, 0, 0],
#  'Sanan_Sjugirov': [6, 2, 1],
#  'oskariot': [4, 0, 0],
#  'gmshanmeruga': [0, 0, 1],
#  'ShimanovAlex': [0, 1, 0],
#  'Wilsonpalencia': [1, 0, 0],
#  'Genghis_K': [2, 4, 0],
#  'Kouzari': [0, 0, 1],
#  'jcgs1030': [1, 0, 0],
#  'Multivitamin73': [1, 1, 0],
#  'MbMaster': [1, 0, 0],
#  'penguingm1': [7, 0, 2],
#  'MaestroASK': [1, 0, 0],
#  'Cruel_Yaro': [0, 0, 1],
#  'GGuseinov': [1, 1, 1],
#  'proxy6': [0, 0, 1],
#  'Elshan1985': [2, 0, 0],
#  'A-Fier': [2, 0, 0],
#  'Fandorine': [8, 0, 1],
#  'ZapataCharlesS': [1, 0, 0],
#  'platy3': [13, 0, 0],
#  'Bugcrusher': [1, 0, 0],
#  'ftorodent': [1, 0, 0],
#  'Indianlad': [3, 2, 1],
#  'feigelag': [2, 0, 0],
#  'sergiochess83': [4, 2, 0],
#  'TomsKantans': [0, 0, 1],
#  'mwpchess': [0, 0, 1],
#  'XiaoKangZhong': [1, 0, 0],
#  'ChessQueen': [4, 0, 0],
#  'SwiftyMcBishop': [0, 0, 1],
#  'grzechu96': [1, 0, 0],
#  'severomorskij': [2, 1, 1],
#  'pastouche06': [1, 0, 0],
#  'EgorGeroev': [1, 0, 0],
#  'SergeiAza': [0, 1, 0],
#  'rubhani': [1, 0, 0],
#  'LawrenceTrent': [1, 0, 1],
#  'ChristopherYoo': [2, 0, 0],
#  'TricksOnly': [1, 0, 0],
#  'Ilja_Semjonovs': [1, 0, 0],
#  'sorito': [1, 0, 0],
#  'Michelangelo': [0, 1, 0],
#  'DrVitman': [1, 0, 0],
#  'GMBenjaminBok': [5, 1, 0],
#  'Msb2': [10, 2, 0],
#  'hermionegrangermagic': [2, 0, 0],
#  'Fins0905': [2, 0, 0],
#  'PaulfromSPb': [2, 0, 0],
#  'Keranke': [2, 0, 0],
#  'TenisMaster': [2, 0, 0],
#  'ohusbands': [1, 0, 0],
#  'mokerslag': [2, 0, 0],
#  'dalmatinac101': [0, 0, 1],
#  'Witik': [1, 0, 3],
#  'ValeriyGrinev': [2, 0, 0],
#  'Khamrakulov_Djurabek': [1, 0, 1],
#  'Fy_Rakotomaharo': [2, 0, 0],
#  'Rodalquilar': [5, 0, 0],
#  'Man-Chuk': [2, 0, 0],
#  'Tobi-Wan-Kenobi': [0, 0, 1],
#  'comedy_of_errors': [1, 0, 0],
#  'BKMZBKMZ': [1, 0, 0],
#  'Batica1984': [1, 0, 0],
#  'temiksmozg': [0, 0, 1],
#  'GMAkobianSTL': [1, 0, 0],
#  'Federer999': [1, 0, 0],
#  'Zaven_ChessMood': [1, 0, 0],
#  'AkshatChandra': [0, 1, 0],
#  'ST-Sandavagur': [1, 0, 0],
#  'dyziotomi99': [1, 0, 0],
#  'GMKrikor': [2, 0, 0],
#  'VladimirBelous': [0, 0, 2],
#  'Alopekos': [1, 0, 0],
#  'gmjlh': [2, 0, 0],
#  'Tjktiger': [0, 0, 1],
#  'albi1999': [2, 0, 0],
#  'PulpanJ': [1, 0, 0],
#  'Shahinyan_ChessMood': [1, 0, 0],
#  'GadimbayliA': [3, 0, 0],
#  'TigranLPetrosyan': [1, 1, 0],
#  'Rakhmanov_Aleksandr': [0, 1, 0],
#  'mouseWLZ': [2, 0, 0],
#  'Paralinch': [1, 1, 0],
#  'FedaMaster': [1, 0, 0],
#  'Swarnapuri': [1, 0, 0],
#  'Alexey_Potapov': [0, 0, 1],
#  'JonahWillow': [3, 0, 0],
#  'Orange_Ghost': [2, 0, 0],
#  'joppie2': [4, 2, 2],
#  'KhalilMousavi77': [1, 0, 0],
#  'vugarrasulov': [4, 0, 2],
#  'gmjoey1': [1, 0, 0],
#  'Gordima': [1, 1, 0],
#  'AryanTari': [5, 0, 1],
#  'KenanGarayev': [1, 0, 0],
#  'Bryakin_Mikhail': [1, 0, 0],
#  'dreamist': [0, 0, 1],
#  'Amirreza_p': [0, 0, 1],
#  'Jenia84': [1, 0, 0],
#  'pedroholly22': [1, 0, 0],
#  'JonasHilwerda': [1, 0, 0],
#  'fastestmindalive': [2, 0, 0],
#  'valeriocarnicelli': [1, 0, 0],
#  'GHANDEEVAM2003': [1, 0, 1],
#  'RegZryt': [1, 0, 0],
#  'PotapovaM': [3, 0, 0],
#  'LuckIsMySkill': [0, 1, 0],
#  'mitrabhaa': [3, 0, 0],
#  'Chempiblinka': [1, 0, 0],
#  'Angry_Twin': [6, 0, 0],
#  'Polish_fighter3000': [1, 0, 0],
#  'AdrianaNikolova': [1, 0, 0],
#  'DenishevM': [1, 0, 0],
#  'ChessWeebs': [1, 0, 0],
#  'temus_galaktionov': [1, 0, 0],
#  'Padenie_Zvezd': [0, 1, 0],
#  'TheFireChess': [1, 0, 0],
#  'jlucasvf': [0, 0, 1],
#  'Gentlejimmy7': [1, 0, 0],
#  'KL31': [1, 0, 0],
#  'bubacik': [0, 0, 1],
#  'INLOVEWITHF': [1, 0, 0],
#  'JozefKneht': [1, 0, 0],
#  'Darhild': [1, 0, 0],
#  'kuli4ik': [4, 2, 0],
#  'alishersuleymenov': [0, 1, 0],
#  'MoonlighT89': [2, 0, 0],
#  'Leonid_Starozhilov': [1, 1, 2],
#  'Borsuk_Konstantin': [1, 0, 0],
#  'crescentmoon2411': [1, 0, 1],
#  'vlad10898': [0, 1, 0],
#  'Artem_Ilyin': [0, 1, 0],
#  'M1711': [0, 1, 0],
#  'politeplayer': [0, 0, 1],
#  'arminmusovic': [1, 0, 0],
#  'Squirlolz': [1, 0, 0],
#  'nubair1198': [0, 0, 1],
#  'Mikhail_Biryukov': [0, 1, 0],
#  'DonChess1984': [1, 0, 0],
#  'Jungle_Jaguar': [3, 0, 0],
#  'cruzravina': [1, 0, 0],
#  'g3god': [1, 0, 0],
#  'vladislavkovalev': [5, 1, 1],
#  'gena217': [2, 0, 0],
#  'Vyacheslav_N': [1, 0, 0],
#  'BeanScreen': [2, 0, 0],
#  'fmshawnrl123': [1, 0, 0],
#  'Rsnr': [1, 0, 0],
#  'Jospem': [12, 4, 2],
#  'swimmerchess': [2, 0, 0],
#  'Micki-taryan': [1, 2, 1],
#  'Zavgorodniy_Serg': [0, 0, 1],
#  'djogrodek1': [1, 0, 0],
#  'RaphCamora': [1, 0, 0],
#  'Disturbed01': [2, 0, 0],
#  'XDPS': [1, 0, 0],
#  'SantoBlue': [2, 0, 1],
#  'MishkaFighter': [1, 0, 0],
#  'OK97': [2, 0, 0],
#  'AnkitGajwa': [1, 0, 0],
#  'doons21': [1, 0, 0],
#  'lupta_robin': [1, 0, 0],
#  'Rud_Makarian': [4, 0, 0],
#  'Jumbo': [1, 1, 0],
#  'BillieKimbah': [6, 1, 0],
#  'Grischuk': [1, 2, 2],
#  'viditchess': [2, 1, 0],
#  'Confer77': [0, 0, 1],
#  'Shuvalov': [2, 0, 0],
#  'troisi': [1, 0, 0],
#  'ENEASZ': [1, 0, 0],
#  'SoltaniciR': [1, 0, 0],
#  'starworld123': [1, 0, 0],
#  'MaximDlugy': [1, 0, 0],
#  'Usurpov': [1, 0, 0],
#  'Reader777': [6, 0, 0],
#  'vinniethepooh': [2, 0, 0],
#  'LiamVrolijk': [2, 0, 0],
#  'Zkid': [8, 0, 1],
#  'Durarbayli': [5, 0, 2],
#  '26andrej26': [1, 0, 0],
#  'RATNAKARAN': [1, 0, 0],
#  'VishnuPrasanna': [0, 1, 0],
#  'SpasKozhuharov': [1, 0, 0],
#  'Shield12': [7, 0, 0],
#  'Onischuk_V': [3, 0, 1],
#  'LittlePeasant': [1, 0, 0],
#  'VerdeNotte': [4, 0, 1],
#  'Oleksandr_Bortnyk': [17, 6, 5],
#  'BernardoRoselli': [1, 0, 0],
#  'UCantHandleDenker': [2, 0, 0],
#  'Lagmantr': [3, 0, 0],
#  'Igrok3069': [2, 0, 0],
#  'BocharovD': [1, 1, 0],
#  'Radzio1987': [0, 1, 0],
#  'Bigfish1995': [8, 4, 2],
#  'MichailovM': [1, 0, 0],
#  'moro182': [1, 1, 0],
#  'vpsetter': [1, 0, 0],
#  'bascheyaro': [2, 0, 0],
#  'Nyzhnyk_Illia': [0, 1, 0],
#  'QuintilianoR': [2, 0, 0],
#  'Zufi1811': [1, 0, 0],
#  'bangchess21': [2, 0, 0],
#  'econpower': [2, 0, 0],
#  'Alexander_Moskalenko': [2, 1, 0],
#  'Kapitan_Bayan': [1, 0, 0],
#  'NTBT_DHS': [1, 0, 1],
#  'Warre': [1, 0, 0],
#  'FMJoseHerrera': [2, 0, 0],
#  'assezde36': [1, 0, 0],
#  'Moon_stone123': [1, 0, 0],
#  'Firegrizzly': [1, 0, 0],
#  'Volodar_Murzin': [1, 0, 0],
#  'Guenplen': [2, 0, 0],
#  'Sankalp_Gupta2003': [1, 0, 0],
#  'Infernal_XaM': [2, 1, 0],
#  'IMHansNiemann': [1, 0, 0],
#  'Karacsonyi_Gellert': [2, 0, 0],
#  'SGchess01': [1, 0, 0],
#  'VovenRogel': [0, 1, 0],
#  'nikitakhoroshev': [1, 0, 0],
#  'KaterynaLagno': [1, 0, 0],
#  'VincentKeymer': [3, 0, 0],
#  'hanzo_hasashi1': [2, 0, 0],
#  'FabianoCaruana': [1, 1, 0],
#  'Caterpiller35': [2, 0, 0],
#  'Zablotsky': [1, 0, 0],
#  'topotun': [1, 0, 0],
#  'exoticprincess': [11, 5, 8],
#  'chessplayer9919': [1, 0, 0],
#  'Legendinunknown': [2, 1, 0],
#  'abykhovsky': [1, 0, 0],
#  'eljanov': [1, 0, 0],
#  'Bazarov04': [1, 0, 0],
#  'Gloomy_Wanderer': [3, 0, 0],
#  'Antipov_Mikhail_Al': [2, 0, 0],
#  'erichansen': [6, 4, 0],
#  'RaunakSadhwani2005': [1, 0, 0],
#  'mortngabriel': [1, 0, 0],
#  'Sashadav97': [2, 0, 0],
#  'Anuar_Is': [1, 0, 0],
#  'Joshukid': [1, 0, 0],
#  'Roman_Ovetchkin': [2, 0, 0],
#  'RobertoJBM': [2, 0, 1],
#  'TimofeevAr': [6, 1, 0],
#  'JoySpaceman': [1, 0, 0],
#  'Maksimus1998': [1, 0, 0],
#  'Evgeny81': [2, 0, 0],
#  'LiemLe': [0, 1, 0],
#  'RedbaronCanada': [1, 0, 0],
#  'Flawless_Fighter': [1, 1, 0],
#  'chessfrendz': [1, 0, 0],
#  'BilodeauA': [6, 1, 0],
#  'rpragchess': [4, 0, 1],
#  'Firouzja2003': [1, 2, 1],
#  'Mikhail_Golubev': [2, 2, 0],
#  'AlexandraBotez': [1, 0, 0],
#  'jhonnyuribe': [1, 0, 0],
#  'JoliyRoger': [1, 0, 0],
#  'GasconJR': [1, 0, 0],
#  'Gabix_94': [1, 0, 0],
#  'daro94': [3, 1, 0],
#  'KarstenHansch': [2, 0, 0],
#  'Pultis': [1, 0, 0],
#  'Supernotar': [2, 0, 0],
#  'David_Paravyan': [1, 0, 0],
#  'mishanick': [8, 7, 1],
#  'lachesisQ': [0, 2, 0],
#  'grunbergmihai': [1, 0, 1],
#  'Savagelittlemole': [1, 0, 0],
#  'Berardino': [1, 0, 0],
#  'TrickyFortem': [1, 0, 0],
#  'Aygehovit1992': [4, 0, 1],
#  'BanjoKazooieN64': [0, 1, 0],
#  'HrvojeZagreb': [0, 1, 0],
#  'K-Nygren': [1, 0, 0],
#  'kuban1991': [1, 0, 1],
#  'Alexsur1981': [2, 0, 1],
#  'Parhamov': [3, 3, 2],
#  'ViditYT': [1, 1, 0],
#  'TigrVShlyape': [10, 3, 1],
#  'r31415': [1, 0, 0],
#  'Love_craft': [2, 0, 0],
#  'GalperinPlaton': [1, 1, 0],
#  'Annawel': [2, 0, 0],
#  'Sibelephant': [2, 0, 2],
#  'djano': [1, 0, 0],
#  'NewBornNow': [1, 0, 2],
#  'Snegokhod': [1, 0, 0],
#  'AmirBagheri78': [1, 0, 0],
#  'Youtube-Kelvinchess': [1, 0, 0],
#  'MPGM': [1, 0, 0],
#  'ShapkinAnatoliy': [1, 0, 0],
#  'hulkmania8949': [2, 0, 0],
#  'horripile': [1, 0, 0],
#  'GM_Crest': [4, 0, 0],
#  'FormerProdigy': [0, 0, 1],
#  'Skatchkov_V': [1, 0, 0],
#  'Rakhimzhan_Alen': [1, 0, 0],
#  'emperor87': [1, 0, 1],
#  'SamuelGhimpu2003': [1, 0, 0],
#  'biostatistician': [1, 0, 0],
#  'Harsha_Bharathakoti': [2, 1, 0],
#  'WIDBIFS': [1, 0, 0],
#  'mjray79': [1, 0, 0],
#  'sara_khm': [1, 0, 0],
#  'vanea_03': [1, 0, 0],
#  'Duhless': [6, 4, 1],
#  'rasmussvane': [6, 3, 2],
#  'GigaQuparadze': [2, 2, 4],
#  'Nadeev_Sergey': [1, 0, 0],
#  'IrishMonkey': [1, 0, 0],
#  '12teen': [3, 1, 0],
#  'KazakhFighter04': [3, 0, 0],
#  'Rondo_Capriccioso': [1, 0, 0],
#  'ChessLover0108': [4, 1, 0],
#  'AlexeiShirov': [2, 0, 0],
#  'BrandonJacobson': [2, 0, 0],
#  'BogdanDeac': [4, 4, 2],
#  'wonderfultime': [10, 5, 2],
#  'Lovkov_Roman': [0, 0, 1],
#  'Srisshhhtea': [0, 1, 0],
#  'Susal_De_Silva': [1, 0, 0],
#  'DenisQ': [1, 0, 0],
#  'Keks2017': [0, 1, 0],
#  'attack2mateU': [4, 0, 0],
#  '2nd_life': [1, 0, 0],
#  'Fighter008': [1, 0, 0],
#  'TheBigBoss04': [1, 0, 2],
#  'Neftegor': [1, 0, 0],
#  'gedeblas': [2, 0, 0],
#  'petrpalachev': [0, 0, 1],
#  'WPWPWP-2015': [4, 0, 0],
#  'ShahMatKanal': [1, 0, 0],
#  'manitodeplomo': [3, 0, 0],
#  'K_A_S_T_O_R': [2, 3, 1],
#  'KuzubovYuriy': [1, 1, 0],
#  'Igor_Lysyj': [1, 0, 0],
#  'anon219': [3, 0, 0],
#  'ChessyInstinct': [1, 0, 0],
#  'chessasuke': [1, 0, 0],
#  'RD4ever': [2, 0, 1],
#  'DariaVoit': [1, 0, 0],
#  'elcandado': [2, 0, 0],
#  'Vuk2000': [2, 0, 0],
#  'amintabatabaei': [5, 2, 0],
#  'EvgenyT': [2, 0, 0],
#  'DrVelja': [1, 1, 0],
#  'DrCeltic': [2, 0, 0],
#  'KaterinaMiroshnik': [1, 0, 0],
#  'Shahaliyev': [2, 0, 1],
#  'Shepherdboy': [1, 0, 0],
#  'Szparu': [1, 0, 0],
#  'SergeyShtyka': [1, 0, 0],
#  'IMRosen': [1, 1, 0],
#  'julinha97': [1, 0, 0],
#  'dragos420': [1, 0, 0],
#  'Krakozia': [1, 0, 0],
#  'bocah_sakit': [0, 0, 2],
#  'erdni1993': [2, 0, 0],
#  'KNCP_719': [1, 0, 0],
#  'Anton_Demchenko': [4, 2, 1],
#  'ram1zan': [0, 0, 1],
#  'Margency': [1, 0, 0],
#  'Stewie_89': [1, 0, 0],
#  'PSvidler': [1, 2, 0],
#  'fearless_guy': [1, 1, 0],
#  'ErikRonka': [2, 0, 0],
#  'Federtiu': [1, 0, 0],
#  'alexrustemov': [6, 0, 0],
#  'baki83': [2, 0, 0],
#  'howitzer14': [2, 1, 0],
#  'francyIM': [2, 0, 0],
#  'Eltaj_Safarli': [1, 0, 1],
#  'sergeikim': [1, 0, 0],
#  'tjychess': [2, 0, 0],
#  'INDIAN-ELEPHANT': [1, 0, 0],
#  'Slovak_fighter2000': [1, 0, 0],
#  'esapunov': [1, 0, 0],
#  'superchess02': [3, 0, 0],
#  'Zhigalko_Sergei': [10, 3, 2],
#  'Sam_ChessMood': [2, 0, 0],
#  'SilviusTiberius': [1, 0, 0],
#  'AleksanderHnydiuk': [2, 0, 0],
#  'Chernobay_Artem': [1, 0, 0],
#  'seorobert1971': [4, 0, 0],
#  'Vaathi_Coming': [1, 0, 0],
#  'martinique24': [1, 0, 0],
#  'Diego_FloresQ': [1, 0, 0],
#  'steka121': [1, 0, 0],
#  'AlexPapasimakopoulos': [1, 0, 0],
#  'Skat2704': [1, 0, 0],
#  'DrawDenied-Twitch': [1, 0, 0],
#  'VladDobrov': [1, 1, 1],
#  'Chopper1905': [2, 0, 0],
#  'Ali-Farahat': [1, 0, 0],
#  'Antidrome': [2, 0, 0],
#  'DeTimmerman': [3, 0, 0],
#  'dropstoneDP': [6, 3, 2],
#  'DuDaKi': [1, 0, 0],
#  'GM_Levan_Pantsulaia': [0, 0, 1],
#  'Guachiney': [1, 0, 0],
#  'AttilaTurzo': [1, 0, 0],
#  'nrvisakh': [2, 0, 0],
#  'Manticore17': [1, 0, 0],
#  'Sadykov_Ramil': [2, 0, 0],
#  'NateSolon': [3, 0, 0],
#  'tlomigtlis': [1, 0, 0],
#  'frederiksvane': [2, 0, 0],
#  'kingmonkey88': [1, 0, 0],
#  'rookoco': [1, 1, 0],
#  'mary-sanna': [1, 0, 0],
#  'Piotrek1979': [1, 0, 0],
#  'MusicCityMaster': [1, 0, 0],
#  'tvjosue': [1, 0, 0],
#  'Vanina1989': [1, 1, 0],
#  'Semen_Khanin': [2, 0, 0],
#  'Jovidon91': [1, 0, 0],
#  'Caracternin123': [1, 0, 0],
#  'GOGIEFF': [0, 0, 1],
#  'PlotnikovPavel': [2, 0, 0],
#  'Mr_Sinigami': [2, 0, 0],
#  'Alexander_Donchenko': [3, 0, 0],
#  'GM_dmitrij': [3, 0, 0],
#  'gonzaga23': [1, 0, 0],
#  'Sammed_Shete': [1, 0, 0],
#  'Didici': [1, 0, 0],
#  'Rainmond': [1, 0, 0],
#  'Alexander_Zubov': [2, 1, 0],
#  'Saqo007': [1, 0, 0],
#  'Zubrrr': [2, 0, 0],
#  'NovakCabarkapa': [1, 0, 0],
#  'TamirNabaty': [1, 0, 0],
#  'eightbyeightchess': [1, 0, 0],
#  'NeverW84M8': [1, 0, 0],
#  'Aradhya2000': [2, 0, 0],
#  'chessdjw': [3, 0, 0],
#  'DenLaz': [0, 5, 1],
#  'AustrianFalcon': [0, 1, 0],
#  'Supzuroke': [1, 0, 0],
#  'delphin11': [1, 0, 0],
#  'champ2005': [4, 1, 2],
#  'Gulkov_Igor': [1, 0, 0],
#  'DmitryMaximov': [4, 0, 0],
#  'timator': [1, 0, 0],
#  'honestgames': [3, 1, 0],
#  'ljuks68': [1, 0, 0],
#  'suyu28': [1, 0, 0],
#  'AlexOstrovskiy': [1, 0, 0],
#  'Andreikka': [2, 1, 0],
#  'Chesseyat004': [1, 0, 0],
#  'mac0504': [1, 0, 0],
#  'blitzking1729': [1, 0, 0],
#  'Arseniy_Nesterov': [1, 1, 0],
#  'Semetey': [1, 0, 0],
#  'Maestro1986': [1, 0, 0],
#  'fyall777': [1, 0, 0],
#  'eldur16': [1, 0, 0],
#  'Bilan_Danila': [2, 0, 0],
#  'TrahtarBelarus': [1, 0, 0],
#  'xamax2000': [1, 0, 1],
#  'Blackmind96': [1, 0, 0],
#  'KhazarBabazada007': [2, 1, 2],
#  'ChessPromotionAlex': [1, 0, 0],
#  'AndrewMaco': [1, 0, 0],
#  'GMCarlosAObregon': [0, 1, 0],
#  'fu24': [1, 0, 0],
#  'AbdulovOrkhan': [1, 0, 0],
#  'karinachess1': [1, 0, 0],
#  'hurricane7791': [1, 0, 0],
#  'ckgchess': [1, 0, 0],
#  'snowlord': [2, 1, 0],
#  'abhijeetgupta': [1, 0, 0],
#  'Sviridov_Valery': [2, 2, 1],
#  'Niclox': [2, 0, 0],
#  'Azerichess': [0, 0, 1],
#  'hongnhung1234': [1, 0, 0],
#  'Iskusnyh': [1, 0, 0],
#  'Twitch_ElhamBlitz05': [2, 0, 0],
#  'MaxLeto': [1, 0, 0],
#  'Talcrifice': [2, 0, 0],
#  'MatyChess1': [2, 0, 0],
#  'Denis_Makhnyov': [0, 1, 0],
#  'MrChampion_Coach': [1, 0, 0],
#  'ymoy': [1, 1, 0],
#  'Tactictic': [2, 0, 0],
#  'Lady_Nika': [1, 0, 0],
#  'Kezin_Roman': [1, 1, 0],
#  'Houdinovic': [1, 0, 1],
#  'Vnebo': [1, 0, 0],
#  'Atousa1': [1, 0, 0],
#  'Meri-Arabidze': [1, 0, 0],
#  'Kostya_Nikologorskiy': [1, 0, 0],
#  'Gusarov91': [1, 0, 0],
#  'sokidze': [1, 0, 0],
#  'ehrenfeld': [2, 0, 0],
#  'remi04': [1, 0, 0],
#  'okriak': [1, 0, 0],
#  'Vugar_Manafov': [0, 1, 0],
#  'nicolasbrunner': [1, 0, 0],
#  'jeetjain': [2, 0, 0],
#  'Korchmar_Vasiliy': [3, 0, 0],
#  'Zhuu96': [1, 0, 0],
#  'jup1978': [1, 0, 0],
#  'mazetofonias': [0, 0, 1],
#  'aa175': [1, 0, 0],
#  'michechess89': [1, 0, 0],
#  'gvanna': [1, 0, 0],
#  'IMAghasiyevKamal': [1, 0, 0],
#  'Dyadya81': [1, 0, 0],
#  'dey2580': [2, 0, 0],
#  'HackingKid98': [0, 0, 1],
#  'boasovietica': [1, 0, 0],
#  'BogdanBelyakov89': [1, 0, 0],
#  'mbojan': [3, 1, 0],
#  'CarlosAlbornoz': [1, 0, 0],
#  'Njal28': [2, 0, 0],
#  'klimkoj': [1, 0, 0],
#  'ILvip11x02': [1, 0, 0],
#  'Dan_Bill': [1, 0, 0],
#  'kpio91': [0, 1, 0],
#  'tdf98pantani': [3, 0, 0],
#  'Marta_gm': [1, 0, 0],
#  'vi_pranav': [1, 0, 0],
#  'ViralduS': [1, 0, 0],
#  'Kobalia': [0, 0, 1],
#  'vova-79': [2, 0, 0],
#  'CarlssonLudvig': [1, 0, 0],
#  'unkiyto': [1, 0, 0],
#  'GMRafpig': [2, 0, 0],
#  'Tomi10': [1, 0, 0],
#  'Kretov_Evgenij': [1, 0, 0],
#  'Sanyura': [1, 0, 0],
#  'SirGerhard': [1, 0, 0],
#  'Masmos97': [1, 0, 0],
#  'Djager97': [1, 0, 0],
#  'bipe137': [4, 0, 0],
#  'Mazetovic': [1, 0, 0],
#  'lefonghua': [1, 0, 0],
#  'SaraciNderim': [1, 0, 0],
#  'WildBizon': [1, 0, 0],
#  'TimurGareyev': [4, 0, 0],
#  'SecretQuality': [0, 1, 0],
#  'M-Mar04': [1, 0, 0],
#  'Abund': [3, 0, 0],
#  'Ward-Tsh': [1, 0, 0],
#  'TanitoluwaAps116': [1, 0, 0],
#  'Ali_rastbod': [1, 0, 0],
#  'DanielDardha2005': [1, 1, 0],
#  'ketster': [1, 0, 0],
#  'MarcoRiehle': [2, 0, 0],
#  'Vincent_Vega95': [1, 0, 1],
#  'EvilMorty23': [1, 0, 0],
#  'Mikhail_Bryakin': [1, 0, 0],
#  'mhebden': [1, 0, 0],
#  'js20000': [1, 0, 0],
#  'GM_shahin': [1, 0, 0],
#  'CM_rui': [1, 0, 0],
#  'azikom': [2, 0, 0],
#  'Hrant_ChessMood': [1, 1, 2],
#  'Airquake': [2, 0, 0],
#  'bazar-wokzal': [1, 0, 0],
#  'COCOLASTICOTTE': [1, 0, 0],
#  'Obsidian-Destroyer': [1, 0, 0],
#  'Shankland': [1, 0, 0],
#  'Arigu07': [1, 0, 0],
#  'GothamChess': [1, 0, 0],
#  'MightyGMpretender': [1, 0, 0],
#  'Experience_Chess': [1, 0, 0],
#  'MrTattaglia': [2, 0, 0],
#  'scandalgod': [1, 0, 0],
#  'MlYAGl': [1, 0, 0],
#  'shimastream': [4, 0, 0],
#  'liczner': [1, 0, 0],
#  'sergoy': [0, 1, 0],
#  'xJOHNTITORx': [1, 0, 0],
#  'tylityli': [1, 0, 0],
#  'Elegance_Riks': [0, 1, 0],
#  'Miguelito': [0, 0, 1],
#  'talman67': [0, 1, 0],
#  'stoleriu': [0, 0, 1],
#  'Aslanov_Umid': [0, 0, 1],
#  'JustaTrickstar': [0, 0, 1],
#  'Patrickgong': [1, 0, 0],
#  'druskacik': [0, 0, 1],
#  'HATilay': [1, 0, 0],
#  'Aborigen_came': [1, 0, 0],
#  'Salem-AR': [2, 2, 3],
#  'ama18': [1, 0, 0],
#  'FGHSMN': [1, 0, 0],
#  'IljaJoke': [1, 0, 0],
#  'Sokoloco': [1, 0, 0],
#  'Nils_03': [1, 0, 0],
#  'ShiroglanTalibov': [1, 0, 0],
#  'ActorXu': [2, 0, 0],
#  'HansOnTwitch': [0, 0, 1],
#  'Tobias_Koelle': [1, 0, 0],
#  'Shubinkirill2003': [1, 0, 0],
#  'bardiya_Daneshvar': [1, 0, 0],
#  'Golubovsky': [1, 0, 0],
#  'Bulldog167': [0, 1, 0],
#  'TheFutureStar2005': [1, 0, 0],
#  'Nikolakis2014': [0, 0, 1],
#  'Suleyman_Chess06': [1, 0, 0],
#  'BegmuratovKh2010': [1, 0, 0],
#  'Nitzan_Steinberg': [1, 1, 0],
#  'sunofadawn': [1, 0, 0],
#  'Vladimir_Zakhartsov': [1, 0, 0],
#  'VitaliyBernadskiy': [0, 1, 0],
#  'Vazabanga': [1, 0, 0],
#  'PLAYER_2006_M': [0, 1, 0],
#  'guillembaches': [1, 0, 0],
#  'cristhiancruzsanchez': [1, 0, 0],
#  'TokChess': [1, 0, 0],
#  'GMWSO': [1, 1, 1],
#  'DonkyDonkyDonkey': [1, 0, 0],
#  'Grandelicious': [2, 0, 0],
#  'jaskol95': [1, 0, 0],
#  'TERMINATOR_PC': [1, 0, 0],
#  'LastGladiator1': [3, 0, 0],
#  'GM_RobertoMogranzini': [0, 0, 1],
#  'Chessmissile07': [1, 0, 0],
#  'KingCyber19': [1, 0, 0],
#  'tteshan': [2, 0, 0],
#  'dennisodessa': [1, 0, 0],
#  'jinbojinbo': [1, 0, 0],
#  'Manukyan_Artak': [1, 0, 0],
#  'Russian_berezka': [1, 0, 0],
#  'Roachelley': [1, 0, 0],
#  'GroovyKettle': [0, 1, 0],
#  'JakubPulpan': [1, 0, 0],
#  'Athanasios2': [1, 0, 0],
#  'Marcus_Harvey': [1, 0, 0],
#  'Caclox': [1, 0, 0],
#  'Coachpoker': [1, 0, 0],
#  'sofaceindisguise': [1, 0, 0],
#  'ajian': [1, 0, 0],
#  'LeRoidesChampions': [1, 0, 0],
#  'Kiborg95': [1, 0, 0],
#  'MetiForce': [1, 0, 0],
#  'BlueWizzard': [1, 0, 0],
#  'VB84': [1, 0, 0],
#  'KingOfTheEverything': [0, 1, 0],
#  'wgraif': [1, 0, 0],
#  'Nf3c5': [1, 0, 0],
#  'Adham_Fawzy': [1, 0, 0],
#  'KobyKalavannan': [1, 0, 0],
#  'viviania': [0, 1, 0],
#  'LiamPutnam2008': [1, 0, 0],
#  'Galileo22': [1, 0, 0],
#  'GoltsevDmitry2000': [0, 1, 0],
#  'domalchukjonasson': [1, 0, 0],
#  'MiFerz44': [1, 0, 0],
#  'Dedic8': [1, 0, 0]}

# %% [markdown]
# ### Opponent played the most

# %%
games_played = []
for key, value in d.items():
    games_played.append([sum(value), key])

sorted(games_played, reverse = True)
# hikaru played the most games against FairChess_on_YouTube, Oleksandr_Bortnyk and exoticprincess
# Out:
# [[30, 'FairChess_on_YouTube'],
#  [28, 'Oleksandr_Bortnyk'],
#  [24, 'exoticprincess'],
#  [18, 'Jospem'],
#  [17, 'wonderfultime'],
#  [16, 'mishanick'],
#  [15, 'jefferyx'],
#  [15, 'Zhigalko_Sergei'],
#  [14, 'TigrVShlyape'],
#  [14, 'Bigfish1995'],
#  [13, 'platy3'],
#  [12, 'Msb2'],
#  [11, 'rasmussvane'],
#  [11, 'dropstoneDP'],
#  [11, 'OparinGrigoriy'],
#  [11, 'Duhless'],
#  [10, 'erichansen'],
#  [10, 'dretch'],
#  [10, 'MITerryble'],
#  [10, 'BogdanDeac'],
#  [9, 'penguingm1'],
#  [9, 'Zkid'],
#  [9, 'Sanan_Sjugirov'],
#  [9, 'Fandorine'],
#  [9, 'DanielNaroditsky'],
#  [8, 'joppie2'],
#  [8, 'Parhamov'],
#  [8, 'LyonBeast'],
#  [8, 'GigaQuparadze'],
#  [8, 'ChessWarrior7197'],
#  [7, 'vladislavkovalev'],
#  [7, 'jcibarra'],
#  [7, 'champ2005'],
#  [7, 'amintabatabaei'],
#  [7, 'TimofeevAr'],
#  [7, 'Shield12'],
#  [7, 'Salem-AR'],
#  [7, 'GMHess'],
#  [7, 'Durarbayli'],
#  [7, 'BilodeauA'],
#  [7, 'BillieKimbah'],
#  [7, 'Beca95'],
#  [7, 'Anton_Demchenko'],
#  [6, 'vugarrasulov'],
#  [6, 'sergiochess83'],
#  [6, 'kuli4ik'],
#  [6, 'chito89'],
#  [6, 'alexrustemov'],
#  [6, 'Reader777'],
#  [6, 'K_A_S_T_O_R'],
#  [6, 'Indianlad'],
#  [6, 'Genghis_K'],
#  [6, 'GMBenjaminBok'],
#  [6, 'DenLaz'],
#  [6, 'Cayse'],
#  [6, 'AryanTari'],
#  [6, 'Angry_Twin'],
#  [5, 'yurisolo'],
#  [5, 'rpragchess'],
#  [5, 'maciek_92'],
#  [5, 'VerdeNotte'],
#  [5, 'Sviridov_Valery'],
#  [5, 'Rodalquilar'],
#  [5, 'KhazarBabazada007'],
#  [5, 'Grischuk'],
#  [5, 'GianmarcoVaR'],
#  [5, 'GeorgMeier'],
#  [5, 'Cryptochess'],
#  [5, 'ChessLover0108'],
#  [5, 'Aygehovit1992'],
#  [4, 'shimastream'],
#  [4, 'severomorskij'],
#  [4, 'seorobert1971'],
#  [4, 'oskariot'],
#  [4, 'mbojan'],
#  [4, 'honestgames'],
#  [4, 'daro94'],
#  [4, 'bipe137'],
#  [4, 'attack2mateU'],
#  [4, 'Witik'],
#  [4, 'WPWPWP-2015'],
#  [4, 'TimurGareyev'],
#  [4, 'Sibelephant'],
#  [4, 'Rud_Makarian'],
#  [4, 'Onischuk_V'],
#  [4, 'Mikhail_Golubev'],
#  [4, 'Micki-taryan'],
#  [4, 'Leonid_Starozhilov'],
#  [4, 'Izoria123'],
#  [4, 'Hrant_ChessMood'],
#  [4, 'GM_Crest'],
#  [4, 'Firouzja2003'],
#  [4, 'DmitryMaximov'],
#  [4, 'ChessQueen'],
#  [4, '12teen'],
#  [3, 'viditchess'],
#  [3, 'tigra'],
#  [3, 'tdf98pantani'],
#  [3, 'superchess02'],
#  [3, 'snowlord'],
#  [3, 'nijat_a'],
#  [3, 'mitrabhaa'],
#  [3, 'manitodeplomo'],
#  [3, 'kleinebeer98'],
#  [3, 'howitzer14'],
#  [3, 'chessdjw'],
#  [3, 'anon219'],
#  [3, 'VladDobrov'],
#  [3, 'VincentKeymer'],
#  [3, 'TheBigBoss04'],
#  [3, 'Shahaliyev'],
#  [3, 'SantoBlue'],
#  [3, 'RobertoJBM'],
#  [3, 'RD4ever'],
#  [3, 'PotapovaM'],
#  [3, 'PSvidler'],
#  [3, 'NewBornNow'],
#  [3, 'NateSolon'],
#  [3, 'Legendinunknown'],
#  [3, 'LastGladiator1'],
#  [3, 'Lagmantr'],
#  [3, 'Korchmar_Vasiliy'],
#  [3, 'KazakhFighter04'],
#  [3, 'Kacparov'],
#  [3, 'Jungle_Jaguar'],
#  [3, 'JonahWillow'],
#  [3, 'Infernal_XaM'],
#  [3, 'Iball95'],
#  [3, 'Harsha_Bharathakoti'],
#  [3, 'Gloomy_Wanderer'],
#  [3, 'GadimbayliA'],
#  [3, 'Gabrielian_Artur'],
#  [3, 'GM_dmitrij'],
#  [3, 'GMWSO'],
#  [3, 'GGuseinov'],
#  [3, 'Dlugy'],
#  [3, 'DeTimmerman'],
#  [3, 'Boryboy'],
#  [3, 'BahadirOzen'],
#  [3, 'Andreikka'],
#  [3, 'Alexsur1981'],
#  [3, 'Alexander_Zubov'],
#  [3, 'Alexander_Moskalenko'],
#  [3, 'Alexander_Donchenko'],
#  [3, 'AlexanderL'],
#  [3, 'Abund'],
#  [3, '9ShMat2'],
#  [3, '1stSecond'],
#  [2, 'zmaj23'],
#  [2, 'ymoy'],
#  [2, 'xamax2000'],
#  [2, 'vova-79'],
#  [2, 'vinniethepooh'],
#  [2, 'tteshan'],
#  [2, 'tjychess'],
#  [2, 'tac49'],
#  [2, 'swimmerchess'],
#  [2, 'rookoco'],
#  [2, 'pKiLz5Rn9b'],
#  [2, 'nrvisakh'],
#  [2, 'mouseWLZ'],
#  [2, 'moro182'],
#  [2, 'mokerslag'],
#  [2, 'megarompa'],
#  [2, 'lachesisQ'],
#  [2, 'kuban1991'],
#  [2, 'jeetjain'],
#  [2, 'iturrizaga'],
#  [2, 'igorkovalenko'],
#  [2, 'hulkmania8949'],
#  [2, 'hermionegrangermagic'],
#  [2, 'hanzo_hasashi1'],
#  [2, 'grunbergmihai'],
#  [2, 'gmjlh'],
#  [2, 'gena217'],
#  [2, 'gedeblas'],
#  [2, 'frederiksvane'],
#  [2, 'francyIM'],
#  [2, 'feigelag'],
#  [2, 'fearless_guy'],
#  [2, 'fastestmindalive'],
#  [2, 'facu57'],
#  [2, 'erdni1993'],
#  [2, 'emperor87'],
#  [2, 'elcandado'],
#  [2, 'ehrenfeld'],
#  [2, 'econpower'],
#  [2, 'dey2580'],
#  [2, 'crescentmoon2411'],
#  [2, 'chessking2151'],
#  [2, 'bocah_sakit'],
#  [2, 'bascheyaro'],
#  [2, 'bangchess21'],
#  [2, 'baki83'],
#  [2, 'azikom'],
#  [2, 'albi1999'],
#  [2, 'Zubrrr'],
#  [2, 'Zlatan56'],
#  [2, 'Zazuliak'],
#  [2, 'ZEN-22'],
#  [2, 'Yaacovn'],
#  [2, 'Vuk2000'],
#  [2, 'VladimirBelous'],
#  [2, 'Vincent_Vega95'],
#  [2, 'ViditYT'],
#  [2, 'Vanina1989'],
#  [2, 'ValeriyGrinev'],
#  [2, 'VMikhalevski'],
#  [2, 'UCantHandleDenker'],
#  [2, 'Twitch_ElhamBlitz05'],
#  [2, 'Tilicheev_Viacheslav'],
#  [2, 'TigranLPetrosyan'],
#  [2, 'TenisMaster'],
#  [2, 'Talcrifice'],
#  [2, 'Tal-Baronfew'],
#  [2, 'Tactictic'],
#  [2, 'Supernotar'],
#  [2, 'Smirnov_Pavel'],
#  [2, 'Shuvalov'],
#  [2, 'SenseiJulio'],
#  [2, 'Semen_Khanin'],
#  [2, 'Sashadav97'],
#  [2, 'Sam_ChessMood'],
#  [2, 'Sadykov_Ramil'],
#  [2, 'Roman_Ovetchkin'],
#  [2, 'QuintilianoR'],
#  [2, 'PlotnikovPavel'],
#  [2, 'PaulfromSPb'],
#  [2, 'Paralinch'],
#  [2, 'Orange_Ghost'],
#  [2, 'OK97'],
#  [2, 'Njal28'],
#  [2, 'Nitzan_Steinberg'],
#  [2, 'Niclox'],
#  [2, 'NTBT_DHS'],
#  [2, 'Multivitamin73'],
#  [2, 'Mr_Sinigami'],
#  [2, 'MrTattaglia'],
#  [2, 'MoonlighT89'],
#  [2, 'MinhGTrAn'],
#  [2, 'MatyChess1'],
#  [2, 'MarcoRiehle'],
#  [2, 'Man-Chuk'],
#  [2, 'Malev212'],
#  [2, 'Lupul_Cenusiu'],
#  [2, 'Love_craft'],
#  [2, 'LiamVrolijk'],
#  [2, 'LawrenceTrent'],
#  [2, 'KuzubovYuriy'],
#  [2, 'Konavets'],
#  [2, 'Khamrakulov_Djurabek'],
#  [2, 'Kezin_Roman'],
#  [2, 'Keranke'],
#  [2, 'KarstenHansch'],
#  [2, 'Karacsonyi_Gellert'],
#  [2, 'KNVB'],
#  [2, 'Jumbo'],
#  [2, 'Imre91'],
#  [2, 'Igrok3069'],
#  [2, 'IMRosen'],
#  [2, 'Houdinovic'],
#  [2, 'Guenplen'],
#  [2, 'GregShahade'],
#  [2, 'Grandelicious'],
#  [2, 'Gordima'],
#  [2, 'Gevorg_Harutjunyan'],
#  [2, 'GalperinPlaton'],
#  [2, 'GMRafpig'],
#  [2, 'GMNeiksans'],
#  [2, 'GMKrikor'],
#  [2, 'GHANDEEVAM2003'],
#  [2, 'Fy_Rakotomaharo'],
#  [2, 'Flawless_Fighter'],
#  [2, 'Fins0905'],
#  [2, 'FabianoCaruana'],
#  [2, 'FMJoseHerrera'],
#  [2, 'EvgenyT'],
#  [2, 'Evgeny81'],
#  [2, 'ErikRonka'],
#  [2, 'Eltaj_Safarli'],
#  [2, 'EltajSafarli'],
#  [2, 'Elshan1985'],
#  [2, 'E-Shaposhnikov'],
#  [2, 'DrVelja'],
#  [2, 'DrCeltic'],
#  [2, 'Dr-Bassem'],
#  [2, 'Disturbed01'],
#  [2, 'DanielDardha2005'],
#  [2, 'ChristopherYoo'],
#  [2, 'Chopper1905'],
#  [2, 'Caterpiller35'],
#  [2, 'BrandonJacobson'],
#  [2, 'BocharovD'],
#  [2, 'Bilan_Danila'],
#  [2, 'BeanScreen'],
#  [2, 'Arseniy_Nesterov'],
#  [2, 'Aradhya2000'],
#  [2, 'Antipov_Mikhail_Al'],
#  [2, 'Antidrome'],
#  [2, 'Annawel'],
#  [2, 'AlexeiShirov'],
#  [2, 'AleksanderHnydiuk'],
#  [2, 'Airquake'],
#  [2, 'ActorXu'],
#  [2, 'A-Fier'],
#  [1, 'yian123'],
#  [1, 'yarosavich'],
#  [1, 'xJOHNTITORx'],
#  [1, 'wgraif'],
#  [1, 'vpsetter'],
#  [1, 'vovkcoach'],
#  [1, 'vlad10898'],
#  [1, 'viviania'],
#  [1, 'vi_pranav'],
#  [1, 'vellottiwizard'],
#  [1, 'vanea_03'],
#  [1, 'valeriocarnicelli'],
#  [1, 'unkiyto'],
#  [1, 'tylityli'],
#  [1, 'tvjosue'],
#  [1, 'troisi'],
#  [1, 'topotun'],
#  [1, 'tlomigtlis'],
#  [1, 'timator'],
#  [1, 'temus_galaktionov'],
#  [1, 'temiksmozg'],
#  [1, 'talman67'],
#  [1, 'swayamsm'],
#  [1, 'suyu28'],
#  [1, 'sunofadawn'],
#  [1, 'stoleriu'],
#  [1, 'steka121'],
#  [1, 'starworld123'],
#  [1, 'spectralsoul'],
#  [1, 'sorito'],
#  [1, 'sokidze'],
#  [1, 'sofaceindisguise'],
#  [1, 'sergoy'],
#  [1, 'sergeikim'],
#  [1, 'scandalgod'],
#  [1, 'sara_khm'],
#  [1, 'rubhani'],
#  [1, 'remi04'],
#  [1, 'ram1zan'],
#  [1, 'r31415'],
#  [1, 'proxy6'],
#  [1, 'politeplayer'],
#  [1, 'petrpalachev'],
#  [1, 'pedroholly22'],
#  [1, 'pastouche06'],
#  [1, 'okriak'],
#  [1, 'ohusbands'],
#  [1, 'nubair1198'],
#  [1, 'nikitakhoroshev'],
#  [1, 'nicolasbrunner'],
#  [1, 'mwpchess'],
#  [1, 'mortngabriel'],
#  [1, 'mjray79'],
#  [1, 'michechess89'],
#  [1, 'mhebden'],
#  [1, 'mazetofonias'],
#  [1, 'mary-sanna'],
#  [1, 'martinique24'],
#  [1, 'mac0504'],
#  [1, 'lupta_robin'],
#  [1, 'lorcho'],
#  [1, 'ljuks68'],
#  [1, 'liczner'],
#  [1, 'lexiel'],
#  [1, 'lefonghua'],
#  [1, 'kpio91'],
#  [1, 'klimkoj'],
#  [1, 'kingmonkey88'],
#  [1, 'ketster'],
#  [1, 'karinachess1'],
#  [1, 'jup1978'],
#  [1, 'julinha97'],
#  [1, 'js20000'],
#  [1, 'jlucasvf'],
#  [1, 'jinbojinbo'],
#  [1, 'jhonnyuribe'],
#  [1, 'jcgs1030'],
#  [1, 'jaskol95'],
#  [1, 'hurricane7791'],
#  [1, 'horripile'],
#  [1, 'hongnhung1234'],
#  [1, 'gvanna'],
#  [1, 'guillembaches'],
#  [1, 'grzechu96'],
#  [1, 'gonzaga23'],
#  [1, 'gmshanmeruga'],
#  [1, 'gmjoey1'],
#  [1, 'g3god'],
#  [1, 'fyall777'],
#  [1, 'fu24'],
#  [1, 'ftorodent'],
#  [1, 'fmshawnrl123'],
#  [1, 'esapunov'],
#  [1, 'eljanov'],
#  [1, 'eldur16'],
#  [1, 'eightbyeightchess'],
#  [1, 'dyziotomi99'],
#  [1, 'druskacik'],
#  [1, 'dreamist'],
#  [1, 'dragos420'],
#  [1, 'doons21'],
#  [1, 'domalchukjonasson'],
#  [1, 'djogrodek1'],
#  [1, 'djano'],
#  [1, 'dennisodessa'],
#  [1, 'delphin11'],
#  [1, 'dalmatinac101'],
#  [1, 'cruzravina'],
#  [1, 'cristhiancruzsanchez'],
#  [1, 'cool64chess'],
#  [1, 'comedy_of_errors'],
#  [1, 'ckgchess'],
#  [1, 'chessplayer9919'],
#  [1, 'chessfrendz'],
#  [1, 'chessdude'],
#  [1, 'chessasuke'],
#  [1, 'chess_player_17'],
#  [1, 'bubacik'],
#  [1, 'boasovietica'],
#  [1, 'blitzking1729'],
#  [1, 'biostatistician'],
#  [1, 'bazar-wokzal'],
#  [1, 'bardiya_Daneshvar'],
#  [1, 'assezde36'],
#  [1, 'arnacman'],
#  [1, 'arminmusovic'],
#  [1, 'amaidel'],
#  [1, 'ama18'],
#  [1, 'alishersuleymenov'],
#  [1, 'ajian'],
#  [1, 'abykhovsky'],
#  [1, 'abhijeetgupta'],
#  [1, 'aa175'],
#  [1, 'Zufi1811'],
#  [1, 'Zhuu96'],
#  [1, 'Zavgorodniy_Serg'],
#  [1, 'Zaven_ChessMood'],
#  [1, 'ZapataCharlesS'],
#  [1, 'Zablotsky'],
#  [1, 'Youtube-Kelvinchess'],
#  [1, 'XiaoKangZhong'],
#  [1, 'XDPS'],
#  [1, 'Winehouse83'],
#  [1, 'Wilsonpalencia'],
#  [1, 'WildBizon'],
#  [1, 'Warre'],
#  [1, 'Ward-Tsh'],
#  [1, 'WIDBIFS'],
#  [1, 'Vyacheslav_N'],
#  [1, 'Vugar_Manafov'],
#  [1, 'VovenRogel'],
#  [1, 'Volodar_Murzin'],
#  [1, 'Vnebo'],
#  [1, 'Vladimir_Zakhartsov'],
#  [1, 'VitaliyBernadskiy'],
#  [1, 'VishnuPrasanna'],
#  [1, 'ViralduS'],
#  [1, 'Vazabanga'],
#  [1, 'Vaathi_Coming'],
#  [1, 'VSERGUEI'],
#  [1, 'VB84'],
#  [1, 'Usurpov'],
#  [1, 'TrickyFortem'],
#  [1, 'TricksOnly'],
#  [1, 'TrahtarBelarus'],
#  [1, 'Tonychess32'],
#  [1, 'TomsKantans'],
#  [1, 'Tomi10'],
#  [1, 'TokChess'],
#  [1, 'Tobias_Koelle'],
#  [1, 'Tobi-Wan-Kenobi'],
#  [1, 'Tjktiger'],
#  [1, 'TheFutureStar2005'],
#  [1, 'TheFireChess'],
#  [1, 'TheCount'],
#  [1, 'Tesla37'],
#  [1, 'TanitoluwaAps116'],
#  [1, 'TamirNabaty'],
#  [1, 'TERMINATOR_PC'],
#  [1, 'Szparu'],
#  [1, 'SwiftyMcBishop'],
#  [1, 'Swarnapuri'],
#  [1, 'Susal_De_Silva'],
#  [1, 'Supzuroke'],
#  [1, 'Suleyman_Chess06'],
#  [1, 'Stewie_89'],
#  [1, 'Srisshhhtea'],
#  [1, 'Squirlolz'],
#  [1, 'SpasKozhuharov'],
#  [1, 'SoltaniciR'],
#  [1, 'Sokoloco'],
#  [1, 'Snegokhod'],
#  [1, 'Slovak_fighter2000'],
#  [1, 'Skatchkov_V'],
#  [1, 'Skat2704'],
#  [1, 'SirGerhard'],
#  [1, 'SilviusTiberius'],
#  [1, 'Shubinkirill2003'],
#  [1, 'ShiroglanTalibov'],
#  [1, 'ShimanovAlex'],
#  [1, 'Shepherdboy'],
#  [1, 'ShapkinAnatoliy'],
#  [1, 'Shankland'],
#  [1, 'Shahinyan_ChessMood'],
#  [1, 'ShahMatKanal'],
#  [1, 'SergeyShtyka'],
#  [1, 'SergeiAza'],
#  [1, 'Semetey'],
#  [1, 'SecretQuality'],
#  [1, 'Savagelittlemole'],
#  [1, 'SaraciNderim'],
#  [1, 'Saqo007'],
#  [1, 'Sanyura'],
#  [1, 'Sankalp_Gupta2003'],
#  [1, 'SamuelGhimpu2003'],
#  [1, 'Sammed_Shete'],
#  [1, 'ST-Sandavagur'],
#  [1, 'SGchess01'],
#  [1, 'Russian_berezka'],
#  [1, 'Rsnr'],
#  [1, 'Rondo_Capriccioso'],
#  [1, 'Roachelley'],
#  [1, 'RitchieBlackmore'],
#  [1, 'RegZryt'],
#  [1, 'RedbaronCanada'],
#  [1, 'RaunakSadhwani2005'],
#  [1, 'RaphCamora'],
#  [1, 'Rakhmanov_Aleksandr'],
#  [1, 'Rakhimzhan_Alen'],
#  [1, 'Rainmond'],
#  [1, 'Radzio1987'],
#  [1, 'RATNAKARAN'],
#  [1, 'Pultis'],
#  [1, 'PulpanJ'],
#  [1, 'Polish_fighter3000'],
#  [1, 'Piotrek1979'],
#  [1, 'Patrickgong'],
#  [1, 'Padenie_Zvezd'],
#  [1, 'PLAYER_2006_M'],
#  [1, 'Obsidian-Destroyer'],
#  [1, 'Nyzhnyk_Illia'],
#  [1, 'NovakCabarkapa'],
#  [1, 'Noukii'],
#  [1, 'Nils_03'],
#  [1, 'Nikolakis2014'],
#  [1, 'Nf3c5'],
#  [1, 'NeverW84M8'],
#  [1, 'Neftegor'],
#  [1, 'Nadeev_Sergey'],
#  [1, 'MusicCityMaster'],
#  [1, 'Mugzyyy'],
#  [1, 'MrChampion_Coach'],
#  [1, 'Mornar1951'],
#  [1, 'Moon_stone123'],
#  [1, 'MlYAGl'],
#  [1, 'MishkaFighter'],
#  [1, 'Mikhail_Bryakin'],
#  [1, 'Mikhail_Biryukov'],
#  [1, 'Miguelito'],
#  [1, 'MightyGMpretender'],
#  [1, 'Michelangelo'],
#  [1, 'MichailovM'],
#  [1, 'MiFerz44'],
#  [1, 'MetiForce'],
#  [1, 'Meri-Arabidze'],
#  [1, 'MbMaster'],
#  [1, 'Mazetovic'],
#  [1, 'MaximDlugy'],
#  [1, 'MaxLeto'],
#  [1, 'Matibar'],
#  [1, 'Masmos97'],
#  [1, 'Marta_gm'],
#  [1, 'Margency'],
#  [1, 'Marcus_Harvey'],
#  [1, 'Manukyan_Artak'],
#  [1, 'Manticore17'],
#  [1, 'Maksimus1998'],
#  [1, 'Maitreia'],
#  [1, 'MaestroASK'],
#  [1, 'Maestro1986'],
#  [1, 'MPGM'],
#  [1, 'M1711'],
#  [1, 'M-Mar04'],
#  [1, 'LuckIsMySkill'],
#  [1, 'Lovkov_Roman'],
#  [1, 'LittlePeasant'],
#  [1, 'LiemLe'],
#  [1, 'LiamPutnam2008'],
#  [1, 'LeRoidesChampions'],
#  [1, 'Lady_Nika'],
#  [1, 'LaStreetCmaMaison'],
#  [1, 'LADIESGET2KNOWME'],
#  [1, 'KyronGriffith'],
#  [1, 'Kretov_Evgenij'],
#  [1, 'Krakozia'],
#  [1, 'Kouzari'],
#  [1, 'Kostya_Nikologorskiy'],
#  [1, 'KobyKalavannan'],
#  [1, 'Kobalia'],
#  [1, 'KingOfTheEverything'],
#  [1, 'KingCyber19'],
#  [1, 'Kiborg95'],
#  [1, 'KhalilMousavi77'],
#  [1, 'KenanGarayev'],
#  [1, 'Keks2017'],
#  [1, 'KaterynaLagno'],
#  [1, 'KaterinaMiroshnik'],
#  [1, 'Kapitan_Bayan'],
#  [1, 'KNCP_719'],
#  [1, 'KL31'],
#  [1, 'K-Nygren'],
#  [1, 'JusticeBot'],
#  [1, 'JustaTrickstar'],
#  [1, 'JozefKneht'],
#  [1, 'JoySpaceman'],
#  [1, 'Jovidon91'],
#  [1, 'Joshukid'],
#  [1, 'JonasHilwerda'],
#  [1, 'JoliyRoger'],
#  [1, 'Jenia84'],
#  [1, 'JakubPulpan'],
#  [1, 'Iskusnyh'],
#  [1, 'IrishMonkey'],
#  [1, 'Ilja_Semjonovs'],
#  [1, 'IljaJoke'],
#  [1, 'Igor_Lysyj'],
#  [1, 'INLOVEWITHF'],
#  [1, 'INDIAN-ELEPHANT'],
#  [1, 'IMHansNiemann'],
#  [1, 'IMAghasiyevKamal'],
#  [1, 'ILvip11x02'],
#  [1, 'HrvojeZagreb'],
#  [1, 'HansOnTwitch'],
#  [1, 'HackingKid98'],
#  [1, 'HATilay'],
#  [1, 'Gusarov91'],
#  [1, 'Gulkov_Igor'],
#  [1, 'Guachiney'],
#  [1, 'GroovyKettle'],
#  [1, 'GrigorGrigorov'],
#  [1, 'GothamChess'],
#  [1, 'Golubovsky'],
#  [1, 'GoltsevDmitry2000'],
#  [1, 'Gentlejimmy7'],
#  [1, 'GasconJR'],
#  [1, 'Galileo22'],
#  [1, 'Gabix_94'],
#  [1, 'GOGIEFF'],
#  [1, 'GMharikrishna'],
#  [1, 'GM_shahin'],
#  [1, 'GM_RobertoMogranzini'],
#  [1, 'GM_Levan_Pantsulaia'],
#  [1, 'GM_Huschenbeth'],
#  [1, 'GMCarlosAObregon'],
#  [1, 'GMAkobianSTL'],
#  [1, 'Frolyanov_D'],
#  [1, 'FormerProdigy'],
#  [1, 'Firegrizzly'],
#  [1, 'Fighter008'],
#  [1, 'Federtiu'],
#  [1, 'Federer999'],
#  [1, 'FedaMaster'],
#  [1, 'FabianEnglert'],
#  [1, 'FGHSMN'],
#  [1, 'Experience_Chess'],
#  [1, 'EvilMorty23'],
#  [1, 'Elegance_Riks'],
#  [1, 'EgorGeroev'],
#  [1, 'ENEASZ'],
#  [1, 'Dyadya81'],
#  [1, 'DuDaKi'],
#  [1, 'DrawDenied-Twitch'],
#  [1, 'DrVitman'],
#  [1, 'DonkyDonkyDonkey'],
#  [1, 'DonChess1984'],
#  [1, 'Djager97'],
#  [1, 'Diego_FloresQ'],
#  [1, 'Didici'],
#  [1, 'DenishevM'],
#  [1, 'Denis_Makhnyov'],
#  [1, 'DenisQ'],
#  [1, 'Dedic8'],
#  [1, 'David_Paravyan'],
#  [1, 'DariaVoit'],
#  [1, 'Darhild'],
#  [1, 'Dan_Bill'],
#  [1, 'Cruel_Yaro'],
#  [1, 'Confer77'],
#  [1, 'Coachpoker'],
#  [1, 'ChessyInstinct'],
#  [1, 'Chessmissile07'],
#  [1, 'Chesseyat004'],
#  [1, 'ChessWeebs'],
#  [1, 'ChessTrener'],
#  [1, 'ChessPromotionAlex'],
#  [1, 'Chernobay_Artem'],
#  [1, 'Chempiblinka'],
#  [1, 'CarlssonLudvig'],
#  [1, 'CarlosAlbornoz'],
#  [1, 'Caracternin123'],
#  [1, 'Caclox'],
#  [1, 'COCOLASTICOTTE'],
#  [1, 'CM_rui'],
#  [1, 'Bulldog167'],
#  [1, 'Bugcrusher'],
#  [1, 'Bryakin_Mikhail'],
#  [1, 'Borsuk_Konstantin'],
#  [1, 'BogdanBelyakov89'],
#  [1, 'BlueWizzard'],
#  [1, 'Blackmind96'],
#  [1, 'BernardoRoselli'],
#  [1, 'Berardino'],
#  [1, 'BellJackson95'],
#  [1, 'BegmuratovKh2010'],
#  [1, 'Bazarov04'],
#  [1, 'Batica1984'],
#  [1, 'BanjoKazooieN64'],
#  [1, 'BKMZBKMZ'],
#  [1, 'Azerichess'],
#  [1, 'AustrianFalcon'],
#  [1, 'AttilaTurzo'],
#  [1, 'Atousa1'],
#  [1, 'Athanasios2'],
#  [1, 'Aslanov_Umid'],
#  [1, 'Artem_Ilyin'],
#  [1, 'ArnaudovP'],
#  [1, 'Arigu07'],
#  [1, 'Anuar_Is'],
#  [1, 'AnkitGajwa'],
#  [1, 'AndreyOstrovskiy'],
#  [1, 'AndrewMaco'],
#  [1, 'Amirreza_p'],
#  [1, 'AmirBagheri78'],
#  [1, 'Alopekos'],
#  [1, 'Ali_rastbod'],
#  [1, 'Ali-Farahat'],
#  [1, 'Alexey_Potapov'],
#  [1, 'AlexandraBotez'],
#  [1, 'AlexPapasimakopoulos'],
#  [1, 'AlexOstrovskiy'],
#  [1, 'AkshatChandra'],
#  [1, 'AdrianaNikolova'],
#  [1, 'Adham_Fawzy'],
#  [1, 'Aborigen_came'],
#  [1, 'AbdulovOrkhan'],
#  [1, '2nd_life'],
#  [1, '26andrej26']]

# %%
# record against FairChess_on_YouTube
# [won, drew, lost]
d[sorted(games_played, reverse = True)[0][1]]
# Out:
# [12, 12, 6]

# %%
# record against Oleksandr_Bortnyk
# [won, drew, lost]
d[sorted(games_played, reverse = True)[1][1]]
# Out:
# [17, 6, 5]

# %%
# record against exoticprincess
# [won, drew, lost]
d[sorted(games_played, reverse = True)[2][1]]
# Out:
# [11, 5, 8]

# %% [markdown]
# ### Best and Worst record

# %%
games_played = []
for key, value in d.items():
    # define performace as wins - losses
    games_played.append([value[0]-value[2], key])

sorted(games_played, reverse = True)
# Out:
# [[13, 'platy3'],
#  [12, 'Oleksandr_Bortnyk'],
#  [10, 'OparinGrigoriy'],
#  [10, 'Msb2'],
#  [10, 'Jospem'],
#  [9, 'TigrVShlyape'],
#  [8, 'wonderfultime'],
#  [8, 'Zhigalko_Sergei'],
#  [7, 'mishanick'],
#  [7, 'jefferyx'],
#  [7, 'Zkid'],
#  [7, 'Shield12'],
#  [7, 'Fandorine'],
#  [6, 'erichansen'],
#  [6, 'alexrustemov'],
#  [6, 'TimofeevAr'],
#  [6, 'Reader777'],
#  [6, 'GMHess'],
#  [6, 'FairChess_on_YouTube'],
#  [6, 'BilodeauA'],
#  [6, 'BillieKimbah'],
#  [6, 'Bigfish1995'],
#  [6, 'Angry_Twin'],
#  [5, 'penguingm1'],
#  [5, 'jcibarra'],
#  [5, 'amintabatabaei'],
#  [5, 'Sanan_Sjugirov'],
#  [5, 'Rodalquilar'],
#  [5, 'GianmarcoVaR'],
#  [5, 'GMBenjaminBok'],
#  [5, 'Duhless'],
#  [4, 'vladislavkovalev'],
#  [4, 'shimastream'],
#  [4, 'sergiochess83'],
#  [4, 'seorobert1971'],
#  [4, 'rasmussvane'],
#  [4, 'oskariot'],
#  [4, 'maciek_92'],
#  [4, 'kuli4ik'],
#  [4, 'dropstoneDP'],
#  [4, 'bipe137'],
#  [4, 'attack2mateU'],
#  [4, 'WPWPWP-2015'],
#  [4, 'TimurGareyev'],
#  [4, 'Rud_Makarian'],
#  [4, 'MITerryble'],
#  [4, 'GM_Crest'],
#  [4, 'DmitryMaximov'],
#  [4, 'Cryptochess'],
#  [4, 'ChessQueen'],
#  [4, 'ChessLover0108'],
#  [4, 'AryanTari'],
#  [3, 'tdf98pantani'],
#  [3, 'superchess02'],
#  [3, 'rpragchess'],
#  [3, 'mitrabhaa'],
#  [3, 'mbojan'],
#  [3, 'manitodeplomo'],
#  [3, 'honestgames'],
#  [3, 'exoticprincess'],
#  [3, 'daro94'],
#  [3, 'chito89'],
#  [3, 'chessdjw'],
#  [3, 'anon219'],
#  [3, 'VincentKeymer'],
#  [3, 'VerdeNotte'],
#  [3, 'PotapovaM'],
#  [3, 'NateSolon'],
#  [3, 'LastGladiator1'],
#  [3, 'Lagmantr'],
#  [3, 'Korchmar_Vasiliy'],
#  [3, 'KazakhFighter04'],
#  [3, 'Jungle_Jaguar'],
#  [3, 'JonahWillow'],
#  [3, 'Iball95'],
#  [3, 'Gloomy_Wanderer'],
#  [3, 'GadimbayliA'],
#  [3, 'Gabrielian_Artur'],
#  [3, 'GM_dmitrij'],
#  [3, 'Durarbayli'],
#  [3, 'DeTimmerman'],
#  [3, 'Cayse'],
#  [3, 'Boryboy'],
#  [3, 'Beca95'],
#  [3, 'Aygehovit1992'],
#  [3, 'Anton_Demchenko'],
#  [3, 'Alexander_Donchenko'],
#  [3, 'Abund'],
#  [3, '12teen'],
#  [2, 'yurisolo'],
#  [2, 'vugarrasulov'],
#  [2, 'vova-79'],
#  [2, 'vinniethepooh'],
#  [2, 'viditchess'],
#  [2, 'tteshan'],
#  [2, 'tjychess'],
#  [2, 'tac49'],
#  [2, 'swimmerchess'],
#  [2, 'snowlord'],
#  [2, 'pKiLz5Rn9b'],
#  [2, 'nrvisakh'],
#  [2, 'mouseWLZ'],
#  [2, 'mokerslag'],
#  [2, 'joppie2'],
#  [2, 'jeetjain'],
#  [2, 'igorkovalenko'],
#  [2, 'hulkmania8949'],
#  [2, 'howitzer14'],
#  [2, 'hermionegrangermagic'],
#  [2, 'hanzo_hasashi1'],
#  [2, 'gmjlh'],
#  [2, 'gena217'],
#  [2, 'gedeblas'],
#  [2, 'frederiksvane'],
#  [2, 'francyIM'],
#  [2, 'feigelag'],
#  [2, 'fastestmindalive'],
#  [2, 'facu57'],
#  [2, 'erdni1993'],
#  [2, 'elcandado'],
#  [2, 'ehrenfeld'],
#  [2, 'econpower'],
#  [2, 'dey2580'],
#  [2, 'chessking2151'],
#  [2, 'champ2005'],
#  [2, 'bascheyaro'],
#  [2, 'bangchess21'],
#  [2, 'baki83'],
#  [2, 'azikom'],
#  [2, 'albi1999'],
#  [2, 'Zubrrr'],
#  [2, 'Zazuliak'],
#  [2, 'ZEN-22'],
#  [2, 'Yaacovn'],
#  [2, 'Vuk2000'],
#  [2, 'ValeriyGrinev'],
#  [2, 'VMikhalevski'],
#  [2, 'UCantHandleDenker'],
#  [2, 'Twitch_ElhamBlitz05'],
#  [2, 'TenisMaster'],
#  [2, 'Talcrifice'],
#  [2, 'Tactictic'],
#  [2, 'Supernotar'],
#  [2, 'Shuvalov'],
#  [2, 'Semen_Khanin'],
#  [2, 'Sashadav97'],
#  [2, 'Sam_ChessMood'],
#  [2, 'Sadykov_Ramil'],
#  [2, 'Roman_Ovetchkin'],
#  [2, 'QuintilianoR'],
#  [2, 'PlotnikovPavel'],
#  [2, 'PaulfromSPb'],
#  [2, 'Orange_Ghost'],
#  [2, 'Onischuk_V'],
#  [2, 'OK97'],
#  [2, 'Njal28'],
#  [2, 'Niclox'],
#  [2, 'Mr_Sinigami'],
#  [2, 'MrTattaglia'],
#  [2, 'MoonlighT89'],
#  [2, 'Mikhail_Golubev'],
#  [2, 'MatyChess1'],
#  [2, 'MarcoRiehle'],
#  [2, 'Man-Chuk'],
#  [2, 'Malev212'],
#  [2, 'Lupul_Cenusiu'],
#  [2, 'Love_craft'],
#  [2, 'LiamVrolijk'],
#  [2, 'Legendinunknown'],
#  [2, 'Konavets'],
#  [2, 'Keranke'],
#  [2, 'KarstenHansch'],
#  [2, 'Karacsonyi_Gellert'],
#  [2, 'KNVB'],
#  [2, 'Izoria123'],
#  [2, 'Infernal_XaM'],
#  [2, 'Indianlad'],
#  [2, 'Imre91'],
#  [2, 'Igrok3069'],
#  [2, 'Harsha_Bharathakoti'],
#  [2, 'Guenplen'],
#  [2, 'GregShahade'],
#  [2, 'Grandelicious'],
#  [2, 'Genghis_K'],
#  [2, 'GMRafpig'],
#  [2, 'GMNeiksans'],
#  [2, 'GMKrikor'],
#  [2, 'Fy_Rakotomaharo'],
#  [2, 'Fins0905'],
#  [2, 'FMJoseHerrera'],
#  [2, 'EvgenyT'],
#  [2, 'Evgeny81'],
#  [2, 'ErikRonka'],
#  [2, 'Elshan1985'],
#  [2, 'DrCeltic'],
#  [2, 'Dr-Bassem'],
#  [2, 'Dlugy'],
#  [2, 'Disturbed01'],
#  [2, 'DanielNaroditsky'],
#  [2, 'ChristopherYoo'],
#  [2, 'Chopper1905'],
#  [2, 'Caterpiller35'],
#  [2, 'BrandonJacobson'],
#  [2, 'BogdanDeac'],
#  [2, 'Bilan_Danila'],
#  [2, 'BeanScreen'],
#  [2, 'BahadirOzen'],
#  [2, 'Aradhya2000'],
#  [2, 'Antipov_Mikhail_Al'],
#  [2, 'Antidrome'],
#  [2, 'Annawel'],
#  [2, 'Andreikka'],
#  [2, 'AlexeiShirov'],
#  [2, 'Alexander_Zubov'],
#  [2, 'Alexander_Moskalenko'],
#  [2, 'AlexanderL'],
#  [2, 'AleksanderHnydiuk'],
#  [2, 'Airquake'],
#  [2, 'ActorXu'],
#  [2, 'A-Fier'],
#  [1, 'ymoy'],
#  [1, 'yian123'],
#  [1, 'yarosavich'],
#  [1, 'xJOHNTITORx'],
#  [1, 'wgraif'],
#  [1, 'vpsetter'],
#  [1, 'vovkcoach'],
#  [1, 'vi_pranav'],
#  [1, 'vellottiwizard'],
#  [1, 'vanea_03'],
#  [1, 'valeriocarnicelli'],
#  [1, 'unkiyto'],
#  [1, 'tylityli'],
#  [1, 'tvjosue'],
#  [1, 'troisi'],
#  [1, 'topotun'],
#  [1, 'tlomigtlis'],
#  [1, 'timator'],
#  [1, 'tigra'],
#  [1, 'temus_galaktionov'],
#  [1, 'swayamsm'],
#  [1, 'suyu28'],
#  [1, 'sunofadawn'],
#  [1, 'steka121'],
#  [1, 'starworld123'],
#  [1, 'spectralsoul'],
#  [1, 'sorito'],
#  [1, 'sokidze'],
#  [1, 'sofaceindisguise'],
#  [1, 'severomorskij'],
#  [1, 'sergeikim'],
#  [1, 'scandalgod'],
#  [1, 'sara_khm'],
#  [1, 'rubhani'],
#  [1, 'rookoco'],
#  [1, 'remi04'],
#  [1, 'r31415'],
#  [1, 'pedroholly22'],
#  [1, 'pastouche06'],
#  [1, 'okriak'],
#  [1, 'ohusbands'],
#  [1, 'nikitakhoroshev'],
#  [1, 'nicolasbrunner'],
#  [1, 'mortngabriel'],
#  [1, 'moro182'],
#  [1, 'mjray79'],
#  [1, 'michechess89'],
#  [1, 'mhebden'],
#  [1, 'megarompa'],
#  [1, 'mary-sanna'],
#  [1, 'martinique24'],
#  [1, 'mac0504'],
#  [1, 'lupta_robin'],
#  [1, 'ljuks68'],
#  [1, 'liczner'],
#  [1, 'lexiel'],
#  [1, 'lefonghua'],
#  [1, 'klimkoj'],
#  [1, 'kleinebeer98'],
#  [1, 'kingmonkey88'],
#  [1, 'ketster'],
#  [1, 'karinachess1'],
#  [1, 'jup1978'],
#  [1, 'julinha97'],
#  [1, 'js20000'],
#  [1, 'jinbojinbo'],
#  [1, 'jhonnyuribe'],
#  [1, 'jcgs1030'],
#  [1, 'jaskol95'],
#  [1, 'hurricane7791'],
#  [1, 'horripile'],
#  [1, 'hongnhung1234'],
#  [1, 'gvanna'],
#  [1, 'guillembaches'],
#  [1, 'grzechu96'],
#  [1, 'gonzaga23'],
#  [1, 'gmjoey1'],
#  [1, 'g3god'],
#  [1, 'fyall777'],
#  [1, 'fu24'],
#  [1, 'ftorodent'],
#  [1, 'fmshawnrl123'],
#  [1, 'fearless_guy'],
#  [1, 'esapunov'],
#  [1, 'eljanov'],
#  [1, 'eldur16'],
#  [1, 'eightbyeightchess'],
#  [1, 'dyziotomi99'],
#  [1, 'dretch'],
#  [1, 'dragos420'],
#  [1, 'doons21'],
#  [1, 'domalchukjonasson'],
#  [1, 'djogrodek1'],
#  [1, 'djano'],
#  [1, 'dennisodessa'],
#  [1, 'delphin11'],
#  [1, 'cruzravina'],
#  [1, 'cristhiancruzsanchez'],
#  [1, 'cool64chess'],
#  [1, 'comedy_of_errors'],
#  [1, 'ckgchess'],
#  [1, 'chessplayer9919'],
#  [1, 'chessfrendz'],
#  [1, 'chessdude'],
#  [1, 'chessasuke'],
#  [1, 'chess_player_17'],
#  [1, 'boasovietica'],
#  [1, 'blitzking1729'],
#  [1, 'biostatistician'],
#  [1, 'bazar-wokzal'],
#  [1, 'bardiya_Daneshvar'],
#  [1, 'assezde36'],
#  [1, 'arnacman'],
#  [1, 'arminmusovic'],
#  [1, 'amaidel'],
#  [1, 'ama18'],
#  [1, 'ajian'],
#  [1, 'abykhovsky'],
#  [1, 'abhijeetgupta'],
#  [1, 'aa175'],
#  [1, 'Zufi1811'],
#  [1, 'Zlatan56'],
#  [1, 'Zhuu96'],
#  [1, 'Zaven_ChessMood'],
#  [1, 'ZapataCharlesS'],
#  [1, 'Zablotsky'],
#  [1, 'Youtube-Kelvinchess'],
#  [1, 'XiaoKangZhong'],
#  [1, 'XDPS'],
#  [1, 'Winehouse83'],
#  [1, 'Wilsonpalencia'],
#  [1, 'WildBizon'],
#  [1, 'Warre'],
#  [1, 'Ward-Tsh'],
#  [1, 'WIDBIFS'],
#  [1, 'Vyacheslav_N'],
#  [1, 'Volodar_Murzin'],
#  [1, 'Vnebo'],
#  [1, 'Vladimir_Zakhartsov'],
#  [1, 'ViralduS'],
#  [1, 'ViditYT'],
#  [1, 'Vazabanga'],
#  [1, 'Vanina1989'],
#  [1, 'Vaathi_Coming'],
#  [1, 'VB84'],
#  [1, 'Usurpov'],
#  [1, 'TrickyFortem'],
#  [1, 'TricksOnly'],
#  [1, 'TrahtarBelarus'],
#  [1, 'Tonychess32'],
#  [1, 'Tomi10'],
#  [1, 'TokChess'],
#  [1, 'Tobias_Koelle'],
#  [1, 'Tilicheev_Viacheslav'],
#  [1, 'TigranLPetrosyan'],
#  [1, 'TheFutureStar2005'],
#  [1, 'TheFireChess'],
#  [1, 'TheCount'],
#  [1, 'Tesla37'],
#  [1, 'TanitoluwaAps116'],
#  [1, 'TamirNabaty'],
#  [1, 'TERMINATOR_PC'],
#  [1, 'Szparu'],
#  [1, 'Swarnapuri'],
#  [1, 'Sviridov_Valery'],
#  [1, 'Susal_De_Silva'],
#  [1, 'Supzuroke'],
#  [1, 'Suleyman_Chess06'],
#  [1, 'Stewie_89'],
#  [1, 'Squirlolz'],
#  [1, 'SpasKozhuharov'],
#  [1, 'SoltaniciR'],
#  [1, 'Sokoloco'],
#  [1, 'Snegokhod'],
#  [1, 'Smirnov_Pavel'],
#  [1, 'Slovak_fighter2000'],
#  [1, 'Skatchkov_V'],
#  [1, 'Skat2704'],
#  [1, 'SirGerhard'],
#  [1, 'SilviusTiberius'],
#  [1, 'Shubinkirill2003'],
#  [1, 'ShiroglanTalibov'],
#  [1, 'Shepherdboy'],
#  [1, 'ShapkinAnatoliy'],
#  [1, 'Shankland'],
#  [1, 'Shahinyan_ChessMood'],
#  [1, 'Shahaliyev'],
#  [1, 'ShahMatKanal'],
#  [1, 'SergeyShtyka'],
#  [1, 'Semetey'],
#  [1, 'Savagelittlemole'],
#  [1, 'SaraciNderim'],
#  [1, 'Saqo007'],
#  [1, 'Sanyura'],
#  [1, 'SantoBlue'],
#  [1, 'Sankalp_Gupta2003'],
#  [1, 'SamuelGhimpu2003'],
#  [1, 'Sammed_Shete'],
#  [1, 'ST-Sandavagur'],
#  [1, 'SGchess01'],
#  [1, 'Russian_berezka'],
#  [1, 'Rsnr'],
#  [1, 'Rondo_Capriccioso'],
#  [1, 'RobertoJBM'],
#  [1, 'Roachelley'],
#  [1, 'RitchieBlackmore'],
#  [1, 'RegZryt'],
#  [1, 'RedbaronCanada'],
#  [1, 'RaunakSadhwani2005'],
#  [1, 'RaphCamora'],
#  [1, 'Rakhimzhan_Alen'],
#  [1, 'Rainmond'],
#  [1, 'RD4ever'],
#  [1, 'RATNAKARAN'],
#  [1, 'Pultis'],
#  [1, 'PulpanJ'],
#  [1, 'Polish_fighter3000'],
#  [1, 'Piotrek1979'],
#  [1, 'Patrickgong'],
#  [1, 'Parhamov'],
#  [1, 'Paralinch'],
#  [1, 'PSvidler'],
#  [1, 'Obsidian-Destroyer'],
#  [1, 'NovakCabarkapa'],
#  [1, 'Nitzan_Steinberg'],
#  [1, 'Nils_03'],
#  [1, 'Nf3c5'],
#  [1, 'NeverW84M8'],
#  [1, 'Neftegor'],
#  [1, 'Nadeev_Sergey'],
#  [1, 'MusicCityMaster'],
#  [1, 'Multivitamin73'],
#  [1, 'Mugzyyy'],
#  [1, 'MrChampion_Coach'],
#  [1, 'Mornar1951'],
#  [1, 'Moon_stone123'],
#  [1, 'MlYAGl'],
#  [1, 'MishkaFighter'],
#  [1, 'Mikhail_Bryakin'],
#  [1, 'MightyGMpretender'],
#  [1, 'MichailovM'],
#  [1, 'MiFerz44'],
#  [1, 'MetiForce'],
#  [1, 'Meri-Arabidze'],
#  [1, 'MbMaster'],
#  [1, 'Mazetovic'],
#  [1, 'MaximDlugy'],
#  [1, 'MaxLeto'],
#  [1, 'Masmos97'],
#  [1, 'Marta_gm'],
#  [1, 'Margency'],
#  [1, 'Marcus_Harvey'],
#  [1, 'Manukyan_Artak'],
#  [1, 'Manticore17'],
#  [1, 'Maksimus1998'],
#  [1, 'Maitreia'],
#  [1, 'MaestroASK'],
#  [1, 'Maestro1986'],
#  [1, 'MPGM'],
#  [1, 'M-Mar04'],
#  [1, 'LyonBeast'],
#  [1, 'LittlePeasant'],
#  [1, 'LiamPutnam2008'],
#  [1, 'LeRoidesChampions'],
#  [1, 'Lady_Nika'],
#  [1, 'LaStreetCmaMaison'],
#  [1, 'LADIESGET2KNOWME'],
#  [1, 'KyronGriffith'],
#  [1, 'KuzubovYuriy'],
#  [1, 'Kretov_Evgenij'],
#  [1, 'Krakozia'],
#  [1, 'Kostya_Nikologorskiy'],
#  [1, 'KobyKalavannan'],
#  [1, 'KingCyber19'],
#  [1, 'Kiborg95'],
#  [1, 'KhalilMousavi77'],
#  [1, 'Kezin_Roman'],
#  [1, 'KenanGarayev'],
#  [1, 'KaterynaLagno'],
#  [1, 'KaterinaMiroshnik'],
#  [1, 'Kapitan_Bayan'],
#  [1, 'Kacparov'],
#  [1, 'K_A_S_T_O_R'],
#  [1, 'KNCP_719'],
#  [1, 'KL31'],
#  [1, 'K-Nygren'],
#  [1, 'JusticeBot'],
#  [1, 'Jumbo'],
#  [1, 'JozefKneht'],
#  [1, 'JoySpaceman'],
#  [1, 'Jovidon91'],
#  [1, 'Joshukid'],
#  [1, 'JonasHilwerda'],
#  [1, 'JoliyRoger'],
#  [1, 'Jenia84'],
#  [1, 'JakubPulpan'],
#  [1, 'Iskusnyh'],
#  [1, 'IrishMonkey'],
#  [1, 'Ilja_Semjonovs'],
#  [1, 'IljaJoke'],
#  [1, 'Igor_Lysyj'],
#  [1, 'INLOVEWITHF'],
#  [1, 'INDIAN-ELEPHANT'],
#  [1, 'IMRosen'],
#  [1, 'IMHansNiemann'],
#  [1, 'IMAghasiyevKamal'],
#  [1, 'ILvip11x02'],
#  [1, 'HATilay'],
#  [1, 'Gusarov91'],
#  [1, 'Gulkov_Igor'],
#  [1, 'Guachiney'],
#  [1, 'GrigorGrigorov'],
#  [1, 'GothamChess'],
#  [1, 'Gordima'],
#  [1, 'Golubovsky'],
#  [1, 'Gentlejimmy7'],
#  [1, 'GasconJR'],
#  [1, 'GalperinPlaton'],
#  [1, 'Galileo22'],
#  [1, 'Gabix_94'],
#  [1, 'GMharikrishna'],
#  [1, 'GM_shahin'],
#  [1, 'GM_Huschenbeth'],
#  [1, 'GMAkobianSTL'],
#  [1, 'Frolyanov_D'],
#  [1, 'Flawless_Fighter'],
#  [1, 'Firegrizzly'],
#  [1, 'Fighter008'],
#  [1, 'Federtiu'],
#  [1, 'Federer999'],
#  [1, 'FedaMaster'],
#  [1, 'FabianoCaruana'],
#  [1, 'FabianEnglert'],
#  [1, 'FGHSMN'],
#  [1, 'Experience_Chess'],
#  [1, 'EvilMorty23'],
#  [1, 'EgorGeroev'],
#  [1, 'ENEASZ'],
#  [1, 'E-Shaposhnikov'],
#  [1, 'Dyadya81'],
#  [1, 'DuDaKi'],
#  [1, 'DrawDenied-Twitch'],
#  [1, 'DrVitman'],
#  [1, 'DrVelja'],
#  [1, 'DonkyDonkyDonkey'],
#  [1, 'DonChess1984'],
#  [1, 'Djager97'],
#  [1, 'Diego_FloresQ'],
#  [1, 'Didici'],
#  [1, 'DenishevM'],
#  [1, 'DenisQ'],
#  [1, 'Dedic8'],
#  [1, 'David_Paravyan'],
#  [1, 'DariaVoit'],
#  [1, 'Darhild'],
#  [1, 'DanielDardha2005'],
#  [1, 'Dan_Bill'],
#  [1, 'Coachpoker'],
#  [1, 'ChessyInstinct'],
#  [1, 'Chessmissile07'],
#  [1, 'Chesseyat004'],
#  [1, 'ChessWeebs'],
#  [1, 'ChessPromotionAlex'],
#  [1, 'Chernobay_Artem'],
#  [1, 'Chempiblinka'],
#  [1, 'CarlssonLudvig'],
#  [1, 'CarlosAlbornoz'],
#  [1, 'Caracternin123'],
#  [1, 'Caclox'],
#  [1, 'COCOLASTICOTTE'],
#  [1, 'CM_rui'],
#  [1, 'Bugcrusher'],
#  [1, 'Bryakin_Mikhail'],
#  [1, 'Borsuk_Konstantin'],
#  [1, 'BogdanBelyakov89'],
#  [1, 'BocharovD'],
#  [1, 'BlueWizzard'],
#  [1, 'Blackmind96'],
#  [1, 'BernardoRoselli'],
#  [1, 'Berardino'],
#  [1, 'BellJackson95'],
#  [1, 'BegmuratovKh2010'],
#  [1, 'Bazarov04'],
#  [1, 'Batica1984'],
#  [1, 'BKMZBKMZ'],
#  [1, 'AttilaTurzo'],
#  [1, 'Atousa1'],
#  [1, 'Athanasios2'],
#  [1, 'Arseniy_Nesterov'],
#  [1, 'ArnaudovP'],
#  [1, 'Arigu07'],
#  [1, 'Anuar_Is'],
#  [1, 'AnkitGajwa'],
#  [1, 'AndreyOstrovskiy'],
#  [1, 'AndrewMaco'],
#  [1, 'AmirBagheri78'],
#  [1, 'Alopekos'],
#  [1, 'Ali_rastbod'],
#  [1, 'Ali-Farahat'],
#  [1, 'Alexsur1981'],
#  [1, 'AlexandraBotez'],
#  [1, 'AlexPapasimakopoulos'],
#  [1, 'AlexOstrovskiy'],
#  [1, 'AdrianaNikolova'],
#  [1, 'Adham_Fawzy'],
#  [1, 'Aborigen_came'],
#  [1, 'AbdulovOrkhan'],
#  [1, '2nd_life'],
#  [1, '26andrej26'],
#  [0, 'zmaj23'],
#  [0, 'xamax2000'],
#  [0, 'vlad10898'],
#  [0, 'viviania'],
#  [0, 'talman67'],
#  [0, 'sergoy'],
#  [0, 'nijat_a'],
#  [0, 'lorcho'],
#  [0, 'lachesisQ'],
#  [0, 'kuban1991'],
#  [0, 'kpio91'],
#  [0, 'grunbergmihai'],
#  [0, 'emperor87'],
#  [0, 'crescentmoon2411'],
#  [0, 'alishersuleymenov'],
#  [0, 'Vugar_Manafov'],
#  [0, 'VovenRogel'],
#  [0, 'VladDobrov'],
#  [0, 'VitaliyBernadskiy'],
#  [0, 'VishnuPrasanna'],
#  [0, 'Vincent_Vega95'],
#  [0, 'VSERGUEI'],
#  [0, 'Srisshhhtea'],
#  [0, 'Sibelephant'],
#  [0, 'ShimanovAlex'],
#  [0, 'SergeiAza'],
#  [0, 'SenseiJulio'],
#  [0, 'SecretQuality'],
#  [0, 'Rakhmanov_Aleksandr'],
#  [0, 'Radzio1987'],
#  [0, 'Padenie_Zvezd'],
#  [0, 'PLAYER_2006_M'],
#  [0, 'Nyzhnyk_Illia'],
#  [0, 'Noukii'],
#  [0, 'NTBT_DHS'],
#  [0, 'MinhGTrAn'],
#  [0, 'Mikhail_Biryukov'],
#  [0, 'Micki-taryan'],
#  [0, 'Michelangelo'],
#  [0, 'M1711'],
#  [0, 'LuckIsMySkill'],
#  [0, 'LiemLe'],
#  [0, 'LawrenceTrent'],
#  [0, 'KingOfTheEverything'],
#  [0, 'KhazarBabazada007'],
#  [0, 'Khamrakulov_Djurabek'],
#  [0, 'Keks2017'],
#  [0, 'HrvojeZagreb'],
#  [0, 'Houdinovic'],
#  [0, 'GroovyKettle'],
#  [0, 'GoltsevDmitry2000'],
#  [0, 'Gevorg_Harutjunyan'],
#  [0, 'GMWSO'],
#  [0, 'GMCarlosAObregon'],
#  [0, 'GHANDEEVAM2003'],
#  [0, 'GGuseinov'],
#  [0, 'Firouzja2003'],
#  [0, 'Eltaj_Safarli'],
#  [0, 'Elegance_Riks'],
#  [0, 'Denis_Makhnyov'],
#  [0, 'ChessWarrior7197'],
#  [0, 'ChessTrener'],
#  [0, 'Bulldog167'],
#  [0, 'BanjoKazooieN64'],
#  [0, 'AustrianFalcon'],
#  [0, 'Artem_Ilyin'],
#  [0, 'AkshatChandra'],
#  [0, '9ShMat2'],
#  [-1, 'temiksmozg'],
#  [-1, 'stoleriu'],
#  [-1, 'ram1zan'],
#  [-1, 'proxy6'],
#  [-1, 'politeplayer'],
#  [-1, 'petrpalachev'],
#  [-1, 'nubair1198'],
#  [-1, 'mwpchess'],
#  [-1, 'mazetofonias'],
#  [-1, 'jlucasvf'],
#  [-1, 'iturrizaga'],
#  [-1, 'gmshanmeruga'],
#  [-1, 'druskacik'],
#  [-1, 'dreamist'],
#  [-1, 'dalmatinac101'],
#  [-1, 'bubacik'],
#  [-1, 'Zavgorodniy_Serg'],
#  [-1, 'TomsKantans'],
#  [-1, 'Tobi-Wan-Kenobi'],
#  [-1, 'Tjktiger'],
#  [-1, 'TheBigBoss04'],
#  [-1, 'Tal-Baronfew'],
#  [-1, 'SwiftyMcBishop'],
#  [-1, 'Salem-AR'],
#  [-1, 'Nikolakis2014'],
#  [-1, 'NewBornNow'],
#  [-1, 'Miguelito'],
#  [-1, 'Matibar'],
#  [-1, 'Lovkov_Roman'],
#  [-1, 'Leonid_Starozhilov'],
#  [-1, 'Kouzari'],
#  [-1, 'Kobalia'],
#  [-1, 'JustaTrickstar'],
#  [-1, 'Hrant_ChessMood'],
#  [-1, 'HansOnTwitch'],
#  [-1, 'HackingKid98'],
#  [-1, 'Grischuk'],
#  [-1, 'GeorgMeier'],
#  [-1, 'GOGIEFF'],
#  [-1, 'GM_RobertoMogranzini'],
#  [-1, 'GM_Levan_Pantsulaia'],
#  [-1, 'FormerProdigy'],
#  [-1, 'EltajSafarli'],
#  [-1, 'DenLaz'],
#  [-1, 'Cruel_Yaro'],
#  [-1, 'Confer77'],
#  [-1, 'Azerichess'],
#  [-1, 'Aslanov_Umid'],
#  [-1, 'Amirreza_p'],
#  [-1, 'Alexey_Potapov'],
#  [-1, '1stSecond'],
#  [-2, 'bocah_sakit'],
#  [-2, 'Witik'],
#  [-2, 'VladimirBelous'],
#  [-2, 'GigaQuparadze']]

# %%
# best performace
d['platy3']
# Out:
# [13, 0, 0]

# %%
# worst performace
d['GigaQuparadze']
# Out:
# [2, 2, 4]

# %%
# let's dive dipper in this bad record
df[((df['White']=='Hikaru') & (df['Black']=='GigaQuparadze'))]
# Out:
# Empty DataFrame
# Columns: [Date, White, Black, Result, WhiteElo, BlackElo, TimeControl, Termination, StartTime, EndDate, EndTime, Tournament, TT]
# Index: []

# %%
# so hikaru never played as white against GigaQuparadze
df[((df['White']=='GigaQuparadze') & (df['Black']=='Hikaru'))]
# Out:
#              Date          White   Black   Result WhiteElo BlackElo  \
# 36329  2020.12.01  GigaQuparadze  Hikaru      0-1     2925     3191
# 37235  2021.01.26  GigaQuparadze  Hikaru      1-0     2995     3240
# 37869  2021.03.09  GigaQuparadze  Hikaru      0-1     2964     3174
# 38725  2021.05.04  GigaQuparadze  Hikaru      1-0     2953     3217
# 39627  2021.06.29  GigaQuparadze  Hikaru      1-0     2970     3153
# 39800  2021.07.13  GigaQuparadze  Hikaru  1/2-1/2     2966     3223
# 39857  2021.07.20  GigaQuparadze  Hikaru      1-0     2995     3257
# 40004  2021.07.27  GigaQuparadze  Hikaru  1/2-1/2     3015     3224
#
#       TimeControl                       Termination StartTime     EndDate  \
# 36329       180+1         Hikaru won by resignation  19:58:25  2020.12.01
# 37235       180+1  GigaQuparadze won by resignation  19:50:44  2021.01.26
# 37869       180+1         Hikaru won by resignation  19:14:25  2021.03.09
# 38725       180+1  GigaQuparadze won by resignation  18:11:38  2021.05.04
# 39627       180+1         GigaQuparadze won on time  17:45:06  2021.06.29
# 39800       180+1           Game drawn by agreement  18:18:46  2021.07.13
# 39857       180+1  GigaQuparadze won by resignation  18:45:53  2021.07.20
# 40004       180+1          Game drawn by repetition  18:45:04  2021.07.27
#
#         EndTime                                         Tournament  TT
# 36329  20:04:15  https://www.chess.com/tournament/live/-titled-...   1
# 37235  19:57:31  https://www.chess.com/tournament/live/-titled-...   1
# 37869  19:21:55  https://www.chess.com/tournament/live/-titled-...   1
# 38725  18:18:45  https://www.chess.com/tournament/live/titled-t...   1
# 39627  17:52:31  https://www.chess.com/tournament/live/titled-t...   1
# 39800  18:24:36  https://www.chess.com/tournament/live/titled-t...   1
# 39857  18:52:59  https://www.chess.com/tournament/live/titled-t...   1
# 40004  18:52:34  https://www.chess.com/tournament/live/titled-t...   1

# %% [markdown]
# ### Number of Stalemate

# %%
df['Stalemate'] = df['Termination'].apply(lambda x: 1 if x[-9:] == 'stalemate' else 0)

# %%
df[df['Stalemate'] == 1]
# Out:
#              Date                 White              Black   Result WhiteElo  \
# 2142   2015.02.24                Hikaru            chito89  1/2-1/2     2847
# 2923   2015.08.04                Beca95             Hikaru  1/2-1/2     2575
# 6156   2016.02.03                dretch             Hikaru  1/2-1/2     2464
# 13358  2017.06.06                Hikaru          maciek_92  1/2-1/2     2907
# 26886  2019.10.01                Hikaru  alishersuleymenov  1/2-1/2     3152
# 34688  2020.09.29             Indianlad             Hikaru  1/2-1/2     2948
# 37424  2021.02.16                Hikaru            IMRosen  1/2-1/2     3201
# 37754  2021.03.02                Hikaru       fearless_guy  1/2-1/2     3222
# 38189  2021.03.30      DanielNaroditsky             Hikaru  1/2-1/2     3051
# 38989  2021.05.18                Hikaru   ChessWarrior7197  1/2-1/2     3202
# 42928  2022.03.08         SecretQuality             Hikaru  1/2-1/2     2531
# 44022  2022.05.31  FairChess_on_YouTube             Hikaru  1/2-1/2     3055
# 44090  2022.06.14                Hikaru  VitaliyBernadskiy  1/2-1/2     3168
# 44330  2022.07.26                Hikaru           Salem-AR  1/2-1/2     3150
#
#       BlackElo TimeControl              Termination StartTime     EndDate  \
# 2142      2593       180+2  Game drawn by stalemate  19:26:27  2015.02.24
# 2923      2850       180+2  Game drawn by stalemate  19:39:55  2015.08.04
# 6156      2831       180+2  Game drawn by stalemate  01:12:47  2016.02.03
# 13358     2534       180+2  Game drawn by stalemate  21:18:57  2017.06.06
# 26886     2712       180+2  Game drawn by stalemate  21:03:36  2019.10.01
# 34688     3231       180+1  Game drawn by stalemate  18:48:24  2020.09.29
# 37424     2610       180+1  Game drawn by stalemate  18:11:28  2021.02.16
# 37754     2856       180+1  Game drawn by stalemate  20:02:09  2021.03.02
# 38189     3211       180+1  Game drawn by stalemate  18:10:34  2021.03.30
# 38989     2930       180+1  Game drawn by stalemate  18:00:34  2021.05.18
# 42928     3101       180+1  Game drawn by stalemate  15:59:47  2022.03.08
# 44022     3163       180+1  Game drawn by stalemate  22:07:44  2022.05.31
# 44090     2827       180+1  Game drawn by stalemate  22:46:55  2022.06.14
# 44330     2992       180+1  Game drawn by stalemate  22:42:25  2022.07.26
#
#         EndTime                                         Tournament  TT  \
# 2142   19:34:37  https://www.chess.com/tournament/live/-titled-...   1
# 2923   19:52:43  https://www.chess.com/tournament/live/-titled-...   1
# 6156   01:22:53  https://www.chess.com/tournament/live/-titled-...   1
# 13358  21:27:34  https://www.chess.com/tournament/live/-titled-...   1
# 26886  21:12:26  https://www.chess.com/tournament/live/-titled-...   1
# 34688  18:57:01  https://www.chess.com/tournament/live/-scc-gra...   1
# 37424  18:20:59  https://www.chess.com/tournament/live/-titled-...   1
# 37754  20:11:36  https://www.chess.com/tournament/live/-titled-...   1
# 38189  18:19:21  https://www.chess.com/tournament/live/-titled-...   1
# 38989  18:09:03  https://www.chess.com/tournament/live/titled-t...   1
# 42928  16:06:04  https://www.chess.com/tournament/live/early-ti...   1
# 44022  22:18:00  https://www.chess.com/tournament/live/late-tit...   1
# 44090  22:55:07  https://www.chess.com/tournament/live/late-tit...   1
# 44330  22:54:46  https://www.chess.com/tournament/live/late-tit...   1
#
#        Stalemate
# 2142           1
# 2923           1
# 6156           1
# 13358          1
# 26886          1
# 34688          1
# 37424          1
# 37754          1
# 38189          1
# 38989          1
# 42928          1
# 44022          1
# 44090          1
# 44330          1

# %%
# hikaru had 14 stalemates in TT
len(df[df['Stalemate'] == 1])
# Out:
# 14

# %% [markdown]
# ### How many TT hikaru won + average number of players for each year

# %%
# we can get this kind of data this way

url_patter = 'https://api.chess.com/pub/tournament/' + tournaments[0].split('/')[-1]
data = requests.get(url_patter).content.decode()
data = json.loads(data)
data
# Out:
# {'name': '*** Titled Tuesday 3|2 Blitz',
#  'url': 'https://www.chess.com/tournament/live/-titled-tuesday-32-blitz-492386',
#  'creator': 'CHESScom',
#  'status': 'finished',
#  'start_time': 1424804400,
#  'finish_time': 1424811809,
#  'settings': {'type': 'swiss',
#   'rules': 'chess',
#   'is_rated': True,
#   'is_official': False,
#   'is_invite_only': False,
#   'user_advance_count': 1,
#   'winner_places': 3,
#   'registered_user_count': 106,
#   'total_rounds': 9,
#   'time_class': 'blitz',
#   'time_control': '180+2'},
#  'players': [{'username': 'eltajsafarli', 'status': 'winner'},
#   {'username': 'jcibarra', 'status': 'registered'},
#   {'username': 'exoticprincess', 'status': 'registered'},
#   {'username': 'lyonbeast', 'status': 'registered'},
#   {'username': 'ar4uha', 'status': 'registered'},
#   {'username': 'georgmeier', 'status': 'registered'},
#   {'username': 'pedromartinez91', 'status': 'registered'},
#   {'username': 'nouki', 'status': 'registered'},
#   {'username': '9shmat2', 'status': 'registered'},
#   {'username': 'akshatchandra', 'status': 'registered'},
#   {'username': 'chito89', 'status': 'registered'},
#   {'username': 'megarompa', 'status': 'registered'},
#   {'username': 'inopov', 'status': 'registered'},
#   {'username': 'zlatan56', 'status': 'registered'},
#   {'username': 'tilicheev_viacheslav', 'status': 'registered'},
#   {'username': 'danielnaroditsky', 'status': 'registered'},
#   {'username': 'tac49', 'status': 'registered'},
#   {'username': 'schemato', 'status': 'registered'},
#   {'username': 'hikaru', 'status': 'registered'},
#   {'username': 'tigrangharamian', 'status': 'registered'},
#   {'username': 'igorkovalenko', 'status': 'registered'},
#   {'username': 'stepanosinovsky', 'status': 'registered'},
#   {'username': 'wonderfultime', 'status': 'registered'},
#   {'username': 'gevorg_harutjunyan', 'status': 'registered'},
#   {'username': 'gmneiksans', 'status': 'registered'}],
#  'rounds': ['https://api.chess.com/pub/tournament/-titled-tuesday-32-blitz-492386/9']}

# %%
data_each_TT = []
for tournament in tournaments:
    tournament = tournament.split('/')
    url_patter = 'https://api.chess.com/pub/tournament/' + tournament[-1]
    
    data = requests.get(url_patter).content.decode()
    data = json.loads(data)
    
    won = 0
    for player_results in data['players']:
        if player_results['username'] == 'hikaru':
            if player_results['status'] == 'winner':
                won = 1

    data_each_TT.append([datetime.date.fromtimestamp(data['start_time']).year, data['settings']['registered_user_count'], won])

# %%
data_each_TT = pd.DataFrame(data_each_TT)
data_each_TT.columns = ['Year', 'Players', 'Won']

# %%
data_each_TT
# Out:
#      Year  Players  Won
# 0    2015      106    0
# 1    2015       95    1
# 2    2015      108    0
# 3    2015       83    1
# 4    2015      128    0
# ..    ...      ...  ...
# 165  2022      295    1
# 166  2022      369    0
# 167  2022      315    0
# 168  2022      385    1
# 169  2022      301    0
#
# [170 rows x 3 columns]

# %%
# average number of player each year
data_each_TT[['Year', 'Players']].groupby(by=['Year']).mean().astype('int')
# Out:
#       Players
# Year
# 2015      105
# 2016      108
# 2017      183
# 2018      309
# 2019      387
# 2020      783
# 2021      601
# 2022      363

# %%
# TT won by Hikaru per year
data_each_TT[['Year', 'Won']].groupby(by=['Year']).sum()
# Out:
#       Won
# Year
# 2015    3
# 2016    4
# 2017    2
# 2018    0
# 2019    1
# 2020    7
# 2021   12
# 2022   19

# %%
# in total Hikaru won 48 TT
data_each_TT[['Year', 'Won']].groupby(by=['Year']).sum().sum()
# Out:
# Won    48
# dtype: int64
